# %% [markdown]
# # Simple API Example Usage
#
# Author: Ryan Fogle

# %%
import os
from cta import TypedBusTracker
from dotenv import load_dotenv

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ## GET Time

# %%
tracker = TypedBusTracker(key=os.environ['CTA_KEY'])
tracker.gettime()
# Out:
# TimeResponse(tm=datetime.datetime(2025, 7, 17, 22, 50, 57))

# %% [markdown]
# ## GET Data Feeds
#
# This is not used for CTA, but included for sake of mimicking CTA HTTP routes.

# %%
tracker.getrtpidatafeeds()
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# File ~/code/cta/src/cta/typedbustracker.py:42, in TypedBusTracker._parse_response(self, response_dict, model_class)
#      40         return ErrorResponse.model_validate(bustime_data)
# ---> 42     return model_class.model_validate(bustime_data)
#      43 except ValidationError as e:
#
# File ~/code/cta/.venv/lib/python3.13/site-packages/pydantic/main.py:703, in BaseModel.model_validate(cls, obj, strict, from_attributes, context, by_alias, by_name)
#     698     raise PydanticUserError(
#     699         'At least one of `by_alias` or `by_name` must be set to True.',
#     700         code='validate-by-alias-and-name-false',
#     701     )
# --> 703 return cls.__pydantic_validator__.validate_python(
#     704     obj, strict=strict, from_attributes=from_attributes, context=context, by_alias=by_alias, by_name=by_name
#     705 )
#
# ValidationError: 1 validation error for RtpiDataFeedsResponse
# rtpidatafeed
#   Field required [type=missing, input_value={'rtpidatafeeds': [{'name...e', 'visible': 'true'}]}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 tracker.getrtpidatafeeds()
#
# File ~/code/cta/src/cta/typedbustracker.py:65, in TypedBusTracker.getrtpidatafeeds(self)
#      59 """Get real time passenger information feeds as typed response
#      60
#      61 Returns:
#      62     RtpiDataFeedsResponse with list of data feeds or ErrorResponse if error
#      63 """
#      64 response = super().getrtpidatafeeds()
# ---> 65 return self._parse_response(response, RtpiDataFeedsResponse)
#
# File ~/code/cta/src/cta/typedbustracker.py:44, in TypedBusTracker._parse_response(self, response_dict, model_class)
#      42     return model_class.model_validate(bustime_data)
#      43 except ValidationError as e:
# ---> 44     raise ValueError(f"Failed to parse API response: {e}")
#
# ValueError: Failed to parse API response: 1 validation error for RtpiDataFeedsResponse
# rtpidatafeed
#   Field required [type=missing, input_value={'rtpidatafeeds': [{'name...e', 'visible': 'true'}]}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing

# %% [markdown]
# ## GET Routes

# %%
tracker.getroutes()
# Out:
# {'bustime-response': {'routes': [{'rt': '1',
#     'rtnm': 'Bronzeville/Union Station',
#     'rtclr': '#336633',
#     'rtdd': '1'},
#    {'rt': '2', 'rtnm': 'Hyde Park Express', 'rtclr': '#993366', 'rtdd': '2'},
#    {'rt': '3', 'rtnm': 'King Drive', 'rtclr': '#009900', 'rtdd': '3'},
#    {'rt': '4', 'rtnm': 'Cottage Grove', 'rtclr': '#cc3300', 'rtdd': '4'},
#    {'rt': 'X4',
#     'rtnm': 'Cottage Grove Express',
#     'rtclr': '#006666',
#     'rtdd': 'X4'},
#    {'rt': '5',
#     'rtnm': 'South Shore Night Bus',
#     'rtclr': '#996633',
#     'rtdd': '5'},
#    {'rt': '6',
#     'rtnm': 'Jackson Park Express',
#     'rtclr': '#ff0066',
#     'rtdd': '6'},
#    {'rt': '7', 'rtnm': 'Harrison', 'rtclr': '#666600', 'rtdd': '7'},
#    {'rt': '8', 'rtnm': 'Halsted', 'rtclr': '#ff00ff', 'rtdd': '8'},
#    {'rt': '8A', 'rtnm': 'South Halsted', 'rtclr': '#66cc66', 'rtdd': '8A'},
#    {'rt': '9', 'rtnm': 'Ashland', 'rtclr': '#cc3366', 'rtdd': '9'},
#    {'rt': 'X9', 'rtnm': 'Ashland Express', 'rtclr': '#33ff00', 'rtdd': 'X9'},
#    {'rt': '10', 'rtnm': 'Museum of S & I', 'rtclr': '#cc66ff', 'rtdd': '10'},
#    {'rt': '11', 'rtnm': 'Lincoln', 'rtclr': '#ff6600', 'rtdd': '11'},
#    {'rt': '12', 'rtnm': 'Roosevelt', 'rtclr': '#33ccff', 'rtdd': '12'},
#    {'rt': 'J14', 'rtnm': 'Jeffery Jump', 'rtclr': '#663399', 'rtdd': 'J14'},
#    {'rt': '15', 'rtnm': 'Jeffery Local', 'rtclr': '#ff9999', 'rtdd': '15'},
#    {'rt': '18', 'rtnm': '16th/18th', 'rtclr': '#6699ff', 'rtdd': '18'},
#    {'rt': '19',
#     'rtnm': 'United Center Express',
#     'rtclr': '#78aa50',
#     'rtdd': '19'},
#    {'rt': '20', 'rtnm': 'Madison', 'rtclr': '#336633', 'rtdd': '20'},
#    {'rt': '21', 'rtnm': 'Cermak', 'rtclr': '#009900', 'rtdd': '21'},
#    {'rt': '22', 'rtnm': 'Clark', 'rtclr': '#cc3300', 'rtdd': '22'},
#    {'rt': '24', 'rtnm': 'Wentworth', 'rtclr': '#9900cc', 'rtdd': '24'},
#    {'rt': '26',
#     'rtnm': 'South Shore Express',
#     'rtclr': '#006666',
#     'rtdd': '26'},
#    {'rt': '28', 'rtnm': 'Stony Island', 'rtclr': '#996633', 'rtdd': '28'},
#    {'rt': '29', 'rtnm': 'State', 'rtclr': '#666600', 'rtdd': '29'},
#    {'rt': '30', 'rtnm': 'South Chicago', 'rtclr': '#ff00ff', 'rtdd': '30'},
#    {'rt': '31', 'rtnm': '31st', 'rtclr': '#00ffff', 'rtdd': '31'},
#    {'rt': '34', 'rtnm': 'South Michigan', 'rtclr': '#cc3366', 'rtdd': '34'},
#    {'rt': '35', 'rtnm': '31st/35th', 'rtclr': '#33ff00', 'rtdd': '35'},
#    {'rt': '36', 'rtnm': 'Broadway', 'rtclr': '#cc66ff', 'rtdd': '36'},
#    {'rt': '37', 'rtnm': 'Sedgwick', 'rtclr': '#993366', 'rtdd': '37'},
#    {'rt': '39', 'rtnm': 'Pershing', 'rtclr': '#33ccff', 'rtdd': '39'},
#    {'rt': '43', 'rtnm': '43rd', 'rtclr': '#cc9966', 'rtdd': '43'},
#    {'rt': '44', 'rtnm': 'Wallace-Racine', 'rtclr': '#ff9999', 'rtdd': '44'},
#    {'rt': '47', 'rtnm': '47th', 'rtclr': '#99cc33', 'rtdd': '47'},
#    {'rt': '48', 'rtnm': 'South Damen', 'rtclr': '#6699ff', 'rtdd': '48'},
#    {'rt': '49', 'rtnm': 'Western', 'rtclr': '#336633', 'rtdd': '49'},
#    {'rt': '49B', 'rtnm': 'North Western', 'rtclr': '#009900', 'rtdd': '49B'},
#    {'rt': 'X49', 'rtnm': 'Western Express', 'rtclr': '#9900cc', 'rtdd': 'X49'},
#    {'rt': '50', 'rtnm': 'Damen', 'rtclr': '#cc3300', 'rtdd': '50'},
#    {'rt': '51', 'rtnm': '51st', 'rtclr': '#006666', 'rtdd': '51'},
#    {'rt': '52', 'rtnm': 'Kedzie', 'rtclr': '#996633', 'rtdd': '52'},
#    {'rt': '52A', 'rtnm': 'South Kedzie', 'rtclr': '#ff0066', 'rtdd': '52A'},
#    {'rt': '53', 'rtnm': 'Pulaski', 'rtclr': '#666600', 'rtdd': '53'},
#    {'rt': '53A', 'rtnm': 'South Pulaski', 'rtclr': '#ff00ff', 'rtdd': '53A'},
#    {'rt': '54', 'rtnm': 'Cicero', 'rtclr': '#cc3366', 'rtdd': '54'},
#    {'rt': '54A',
#     'rtnm': 'North Cicero/Skokie Blvd.',
#     'rtclr': '#33ff00',
#     'rtdd': '54A'},
#    {'rt': '54B', 'rtnm': 'South Cicero', 'rtclr': '#cc66ff', 'rtdd': '54B'},
#    {'rt': '55', 'rtnm': 'Garfield', 'rtclr': '#33ccff', 'rtdd': '55'},
#    {'rt': '55A', 'rtnm': '55th/Austin', 'rtclr': '#cc9966', 'rtdd': '55A'},
#    {'rt': '55N',
#     'rtnm': '55th/Narragansett',
#     'rtclr': '#ff9999',
#     'rtdd': '55N'},
#    {'rt': '56', 'rtnm': 'Milwaukee', 'rtclr': '#6699ff', 'rtdd': '56'},
#    {'rt': '57', 'rtnm': 'Laramie', 'rtclr': '#993366', 'rtdd': '57'},
#    {'rt': '59', 'rtnm': '59th/61st', 'rtclr': '#009900', 'rtdd': '59'},
#    {'rt': '60', 'rtnm': 'Blue Island/26th', 'rtclr': '#9900cc', 'rtdd': '60'},
#    {'rt': '62', 'rtnm': 'Archer', 'rtclr': '#cc3300', 'rtdd': '62'},
#    {'rt': '62H', 'rtnm': 'Archer/Harlem', 'rtclr': '#006666', 'rtdd': '62H'},
#    {'rt': '63', 'rtnm': '63rd', 'rtclr': '#996633', 'rtdd': '63'},
#    {'rt': '63W', 'rtnm': 'West 63rd', 'rtclr': '#ff0066', 'rtdd': '63W'},
#    {'rt': '65', 'rtnm': 'Grand', 'rtclr': '#ff00ff', 'rtdd': '65'},
#    {'rt': '66', 'rtnm': 'Chicago', 'rtclr': '#66cc66', 'rtdd': '66'},
#    {'rt': '67', 'rtnm': '67th-69th-71st', 'rtclr': '#cc3366', 'rtdd': '67'},
#    {'rt': '68', 'rtnm': 'Northwest Highway', 'rtclr': '#33ff00', 'rtdd': '68'},
#    {'rt': '70', 'rtnm': 'Division', 'rtclr': '#ff6600', 'rtdd': '70'},
#    {'rt': '71', 'rtnm': '71st/South Shore', 'rtclr': '#33ccff', 'rtdd': '71'},
#    {'rt': '72', 'rtnm': 'North', 'rtclr': '#cc9966', 'rtdd': '72'},
#    {'rt': '73', 'rtnm': 'Armitage', 'rtclr': '#ff9999', 'rtdd': '73'},
#    {'rt': '74', 'rtnm': 'Fullerton', 'rtclr': '#99cc33', 'rtdd': '74'},
#    {'rt': '75', 'rtnm': '74th-75th', 'rtclr': '#6699ff', 'rtdd': '75'},
#    {'rt': '76', 'rtnm': 'Diversey', 'rtclr': '#336633', 'rtdd': '76'},
#    {'rt': '77', 'rtnm': 'Belmont', 'rtclr': '#993366', 'rtdd': '77'},
#    {'rt': '78', 'rtnm': 'Montrose', 'rtclr': '#009900', 'rtdd': '78'},
#    {'rt': '79', 'rtnm': '79th', 'rtclr': '#9900cc', 'rtdd': '79'},
#    {'rt': '80', 'rtnm': 'Irving Park', 'rtclr': '#cc3300', 'rtdd': '80'},
#    {'rt': '81', 'rtnm': 'Lawrence', 'rtclr': '#996633', 'rtdd': '81'},
#    {'rt': '81W', 'rtnm': 'West Lawrence', 'rtclr': '#ff0066', 'rtdd': '81W'},
#    {'rt': '82', 'rtnm': 'Kimball-Homan', 'rtclr': '#666600', 'rtdd': '82'},
#    {'rt': '84', 'rtnm': 'Peterson', 'rtclr': '#ff00ff', 'rtdd': '84'},
#    {'rt': '85', 'rtnm': 'Central', 'rtclr': '#66cc66', 'rtdd': '85'},
#    {'rt': '85A', 'rtnm': 'North Central', 'rtclr': '#cc3366', 'rtdd': '85A'},
#    {'rt': '86',
#     'rtnm': 'Narragansett/Ridgeland',
#     'rtclr': '#33ff00',
#     'rtdd': '86'},
#    {'rt': '87', 'rtnm': '87th', 'rtclr': '#cc66ff', 'rtdd': '87'},
#    {'rt': '88', 'rtnm': 'Higgins', 'rtclr': '#ff6600', 'rtdd': '88'},
#    {'rt': '90', 'rtnm': 'Harlem', 'rtclr': '#33ccff', 'rtdd': '90'},
#    {'rt': '91', 'rtnm': 'Austin', 'rtclr': '#ff9999', 'rtdd': '91'},
#    {'rt': '92', 'rtnm': 'Foster', 'rtclr': '#99cc33', 'rtdd': '92'},
#    {'rt': '93', 'rtnm': 'California/Dodge', 'rtclr': '#6699ff', 'rtdd': '93'},
#    {'rt': '94', 'rtnm': 'California', 'rtclr': '#336633', 'rtdd': '94'},
#    {'rt': '95', 'rtnm': '95th', 'rtclr': '#00ffff', 'rtdd': '95'},
#    {'rt': '96', 'rtnm': 'Lunt', 'rtclr': '#9900cc', 'rtdd': '96'},
#    {'rt': '97', 'rtnm': 'Skokie', 'rtclr': '#cc3300', 'rtdd': '97'},
#    {'rt': '100',
#     'rtnm': 'Jeffery Manor Express',
#     'rtclr': '#996633',
#     'rtdd': '100'},
#    {'rt': '103', 'rtnm': 'West 103rd', 'rtclr': '#ff0066', 'rtdd': '103'},
#    {'rt': '106', 'rtnm': 'East 103rd', 'rtclr': '#666600', 'rtdd': '106'},
#    {'rt': '108', 'rtnm': 'Halsted/95th', 'rtclr': '#ff00ff', 'rtdd': '108'},
#    {'rt': '111',
#     'rtnm': '111th/King Drive',
#     'rtclr': '#66cc66',
#     'rtdd': '111'},
#    {'rt': '111A',
#     'rtnm': 'Pullman Shuttle',
#     'rtclr': '#ff3333',
#     'rtdd': '111A'},
#    {'rt': '112', 'rtnm': 'Vincennes/111th', 'rtclr': '#cc3366', 'rtdd': '112'},
#    {'rt': '115', 'rtnm': 'Pullman/115th', 'rtclr': '#996633', 'rtdd': '115'},
#    {'rt': '119', 'rtnm': 'Michigan/119th', 'rtclr': '#33ff00', 'rtdd': '119'},
#    {'rt': '120',
#     'rtnm': 'Ogilvie/Streeterville Express',
#     'rtclr': '#cc66ff',
#     'rtdd': '120'},
#    {'rt': '121',
#     'rtnm': 'Union/Streeterville Express',
#     'rtclr': '#ff6600',
#     'rtdd': '121'},
#    {'rt': '124', 'rtnm': 'Navy Pier', 'rtclr': '#ff9999', 'rtdd': '124'},
#    {'rt': '125',
#     'rtnm': 'Water Tower Express',
#     'rtclr': '#99cc33',
#     'rtdd': '125'},
#    {'rt': '126', 'rtnm': 'Jackson', 'rtclr': '#6699ff', 'rtdd': '126'},
#    {'rt': '130', 'rtnm': 'Museum Campus', 'rtclr': '#ff3333', 'rtdd': '130'},
#    {'rt': '134',
#     'rtnm': 'Stockton/LaSalle Express',
#     'rtclr': '#009900',
#     'rtdd': '134'},
#    {'rt': '135',
#     'rtnm': 'Clarendon/LaSalle Express',
#     'rtclr': '#9900cc',
#     'rtdd': '135'},
#    {'rt': '136',
#     'rtnm': 'Sheridan/LaSalle Express',
#     'rtclr': '#cc3300',
#     'rtdd': '136'},
#    {'rt': '143',
#     'rtnm': 'Stockton/Michigan Express',
#     'rtclr': '#006666',
#     'rtdd': '143'},
#    {'rt': '146',
#     'rtnm': 'Inner Lake Shore/Michigan Exp.',
#     'rtclr': '#666600',
#     'rtdd': '146'},
#    {'rt': '147',
#     'rtnm': 'Outer DuSable Lake Shore Exp.',
#     'rtclr': '#ff00ff',
#     'rtdd': '147'},
#    {'rt': '148',
#     'rtnm': 'Clarendon/Michigan Express',
#     'rtclr': '#66cc66',
#     'rtdd': '148'},
#    {'rt': '151', 'rtnm': 'Sheridan', 'rtclr': '#cc3366', 'rtdd': '151'},
#    {'rt': '152', 'rtnm': 'Addison', 'rtclr': '#33ff00', 'rtdd': '152'},
#    {'rt': '155', 'rtnm': 'Devon', 'rtclr': '#cc66ff', 'rtdd': '155'},
#    {'rt': '156', 'rtnm': 'LaSalle', 'rtclr': '#ff6600', 'rtdd': '156'},
#    {'rt': '157',
#     'rtnm': 'Streeterville/Taylor',
#     'rtclr': '#33ccff',
#     'rtdd': '157'},
#    {'rt': '165', 'rtnm': 'West 65th', 'rtclr': '#cc9966', 'rtdd': '165'},
#    {'rt': '169',
#     'rtnm': '69th-UPS Express',
#     'rtclr': '#99cc33',
#     'rtdd': '169'},
#    {'rt': '171',
#     'rtnm': 'U. of Chicago/Hyde Park',
#     'rtclr': '#336633',
#     'rtdd': '171'},
#    {'rt': '172',
#     'rtnm': 'U. of Chicago/Kenwood',
#     'rtclr': '#993366',
#     'rtdd': '172'},
#    {'rt': '192',
#     'rtnm': 'U. of Chicago Hospitals Express',
#     'rtclr': '#cc3300',
#     'rtdd': '192'},
#    {'rt': '201', 'rtnm': 'Central/Ridge', 'rtclr': '#996633', 'rtdd': '201'},
#    {'rt': '206',
#     'rtnm': 'Evanston Circulator',
#     'rtclr': '#666600',
#     'rtdd': '206'}]}}

# %% [markdown]
# ## GET Directions

# %%
tracker.getdirections(rt='8')
# Out:
# {'bustime-response': {'directions': [{'id': 'Northbound',
#     'name': 'Northbound'},
#    {'id': 'Southbound', 'name': 'Southbound'}]}}

# %% [markdown]
# ## GET Stops

# %%
tracker.getstops(rt='8', dir='Southbound')
# Out:
# {'bustime-response': {'stops': [{'stpid': '5776',
#     'stpnm': '1700 N Halsted',
#     'lat': 41.911779000001,
#     'lon': -87.648394},
#    {'stpid': '5774',
#     'stpnm': '1900 N Halsted',
#     'lat': 41.916024999999,
#     'lon': -87.648524},
#    {'stpid': '5812',
#     'stpnm': '2300 S Halsted ',
#     'lat': 41.850904999999,
#     'lon': -87.646533},
#    {'stpid': '5848',
#     'stpnm': '6400 S Halsted',
#     'lat': 41.778039000001,
#     'lon': -87.644870999999},
#    {'stpid': '5804',
#     'stpnm': 'Halsted & 14th Place',
#     'lat': 41.862536000001,
#     'lon': -87.646866999999},
#    {'stpid': '5806',
#     'stpnm': 'Halsted & 16th Street',
#     'lat': 41.859465000001,
#     'lon': -87.646773000001},
#    {'stpid': '17904',
#     'stpnm': 'Halsted & 18th Street',
#     'lat': 41.857250000001,
#     'lon': -87.646714000002},
#    {'stpid': '17905',
#     'stpnm': 'Halsted & 26th Street',
#     'lat': 41.845006,
#     'lon': -87.646532000001},
#    {'stpid': '5815',
#     'stpnm': 'Halsted & 28th Street',
#     'lat': 41.843603999999,
#     'lon': -87.646509},
#    {'stpid': '18213',
#     'stpnm': 'Halsted & 29th Street',
#     'lat': 41.841317000001,
#     'lon': -87.646441000001},
#    {'stpid': '5817',
#     'stpnm': 'Halsted & 30th Street',
#     'lat': 41.840026000001,
#     'lon': -87.646417000002},
#    {'stpid': '17157',
#     'stpnm': 'Halsted & 31st Street',
#     'lat': 41.837635000001,
#     'lon': -87.646353999999},
#    {'stpid': '17123',
#     'stpnm': 'Halsted & 32nd Street',
#     'lat': 41.836176000001,
#     'lon': -87.646310000001},
#    {'stpid': '5820',
#     'stpnm': 'Halsted & 33rd Street',
#     'lat': 41.834495,
#     'lon': -87.646269999998},
#    {'stpid': '5821',
#     'stpnm': 'Halsted & 34th Street ',
#     'lat': 41.832803999999,
#     'lon': -87.646231999999},
#    {'stpid': '5822',
#     'stpnm': 'Halsted & 35th Street',
#     'lat': 41.830912000001,
#     'lon': -87.646201000001},
#    {'stpid': '5823',
#     'stpnm': 'Halsted & 36th Street ',
#     'lat': 41.82878,
#     'lon': -87.646140000002},
#    {'stpid': '17595',
#     'stpnm': 'Halsted & 37th Street',
#     'lat': 41.82734,
#     'lon': -87.646100000001},
#    {'stpid': '5825',
#     'stpnm': 'Halsted & 38th Street ',
#     'lat': 41.825726999999,
#     'lon': -87.646065999999},
#    {'stpid': '5827',
#     'stpnm': 'Halsted & 41st Street',
#     'lat': 41.820213,
#     'lon': -87.645930999999},
#    {'stpid': '5150',
#     'stpnm': 'Halsted & 42nd Street',
#     'lat': 41.817558999999,
#     'lon': -87.645861},
#    {'stpid': '17170',
#     'stpnm': 'Halsted & 43rd Place',
#     'lat': 41.814509000001,
#     'lon': -87.645777},
#    {'stpid': '17060',
#     'stpnm': 'Halsted & 43rd Street',
#     'lat': 41.815874999999,
#     'lon': -87.64581},
#    {'stpid': '17158',
#     'stpnm': 'Halsted & 45th Street',
#     'lat': 41.812157999999,
#     'lon': -87.645727},
#    {'stpid': '5155',
#     'stpnm': 'Halsted & 46th Street',
#     'lat': 41.810345,
#     'lon': -87.645680999999},
#    {'stpid': '16127',
#     'stpnm': 'Halsted & 47th Street',
#     'lat': 41.808529000001,
#     'lon': -87.645638000001},
#    {'stpid': '5829',
#     'stpnm': 'Halsted & 48th Street',
#     'lat': 41.807158999999,
#     'lon': -87.645588000001},
#    {'stpid': '5830',
#     'stpnm': 'Halsted & 49th Street',
#     'lat': 41.805541,
#     'lon': -87.645541},
#    {'stpid': '5831',
#     'stpnm': 'Halsted & 50th Street',
#     'lat': 41.803505999999,
#     'lon': -87.645481999999},
#    {'stpid': '15023',
#     'stpnm': 'Halsted & 51st Street',
#     'lat': 41.801359999999,
#     'lon': -87.645435},
#    {'stpid': '5833',
#     'stpnm': 'Halsted & 52nd Street',
#     'lat': 41.799895,
#     'lon': -87.645399999999},
#    {'stpid': '17950',
#     'stpnm': 'Halsted & 53rd Street',
#     'lat': 41.797531000001,
#     'lon': -87.64534},
#    {'stpid': '5835',
#     'stpnm': 'Halsted & 54th Street',
#     'lat': 41.796182,
#     'lon': -87.645302999999},
#    {'stpid': '5838',
#     'stpnm': 'Halsted & 56th Street',
#     'lat': 41.792594999999,
#     'lon': -87.645209999998},
#    {'stpid': '5839',
#     'stpnm': 'Halsted & 57th Street',
#     'lat': 41.790780999999,
#     'lon': -87.645162000001},
#    {'stpid': '5840',
#     'stpnm': 'Halsted & 58th Street',
#     'lat': 41.788979000001,
#     'lon': -87.645116999999},
#    {'stpid': '5841',
#     'stpnm': 'Halsted & 59th Street',
#     'lat': 41.787191,
#     'lon': -87.64508},
#    {'stpid': '5842',
#     'stpnm': 'Halsted & 60th Street ',
#     'lat': 41.785306999999,
#     'lon': -87.645043000002},
#    {'stpid': '17373',
#     'stpnm': 'Halsted & 61st Street',
#     'lat': 41.783072000001,
#     'lon': -87.644987000001},
#    {'stpid': '15873',
#     'stpnm': 'Halsted & 63rd Parkway',
#     'lat': 41.781846,
#     'lon': -87.644960000001},
#    {'stpid': '15875',
#     'stpnm': 'Halsted & 63rd Street (Green Line)',
#     'lat': 41.779376000001,
#     'lon': -87.644862999998},
#    {'stpid': '15876',
#     'stpnm': 'Halsted & 65th Street',
#     'lat': 41.775765,
#     'lon': -87.644795},
#    {'stpid': '5850',
#     'stpnm': 'Halsted & 66th Street',
#     'lat': 41.774403999999,
#     'lon': -87.644768000002},
#    {'stpid': '5852',
#     'stpnm': 'Halsted & 68th Street',
#     'lat': 41.770769,
#     'lon': -87.64465},
#    {'stpid': '14496',
#     'stpnm': 'Halsted & 69th Street',
#     'lat': 41.768388999999,
#     'lon': -87.644593},
#    {'stpid': '5854',
#     'stpnm': 'Halsted & 70th Street',
#     'lat': 41.767121,
#     'lon': -87.644550999999},
#    {'stpid': '5855',
#     'stpnm': 'Halsted & 71st Street',
#     'lat': 41.765313999999,
#     'lon': -87.644502},
#    {'stpid': '5856',
#     'stpnm': 'Halsted & 72nd Street',
#     'lat': 41.763534999999,
#     'lon': -87.644464999999},
#    {'stpid': '5857',
#     'stpnm': 'Halsted & 73rd Street',
#     'lat': 41.761677,
#     'lon': -87.644418999999},
#    {'stpid': '14818',
#     'stpnm': 'Halsted & 74th Street',
#     'lat': 41.759517,
#     'lon': -87.644356},
#    {'stpid': '5859',
#     'stpnm': 'Halsted & 75th Street ',
#     'lat': 41.758557,
#     'lon': -87.644338},
#    {'stpid': '5860',
#     'stpnm': 'Halsted & 75th Street ',
#     'lat': 41.757428,
#     'lon': -87.644305999999},
#    {'stpid': '5861',
#     'stpnm': 'Halsted & 76th Street',
#     'lat': 41.756206000001,
#     'lon': -87.64428},
#    {'stpid': '15086',
#     'stpnm': 'Halsted & 77th Street',
#     'lat': 41.754011000001,
#     'lon': -87.644217},
#    {'stpid': '5863',
#     'stpnm': 'Halsted & 78th Street',
#     'lat': 41.752605999999,
#     'lon': -87.644187999999},
#    {'stpid': '5864',
#     'stpnm': 'Halsted & 79th Street',
#     'lat': 41.750764999999,
#     'lon': -87.644159999999},
#    {'stpid': '17472',
#     'stpnm': 'Halsted & 79th Street Terminal',
#     'lat': 41.749793000001,
#     'lon': -87.643614999998},
#    {'stpid': '14901',
#     'stpnm': 'Halsted & Addison',
#     'lat': 41.946935000001,
#     'lon': -87.649554999999},
#    {'stpid': '5761',
#     'stpnm': 'Halsted & Aldine',
#     'lat': 41.941912999999,
#     'lon': -87.649409000001},
#    {'stpid': '5769',
#     'stpnm': 'Halsted & Altgeld',
#     'lat': 41.927222,
#     'lon': -87.648923},
#    {'stpid': '18468',
#     'stpnm': 'Halsted & Armitage',
#     'lat': 41.917924,
#     'lon': -87.648602999999},
#    {'stpid': '1349',
#     'stpnm': 'Halsted & Belden',
#     'lat': 41.923765999999,
#     'lon': -87.648787},
#    {'stpid': '14906',
#     'stpnm': 'Halsted & Belmont',
#     'lat': 41.939709,
#     'lon': -87.649349},
#    {'stpid': '5779',
#     'stpnm': 'Halsted & Blackhawk',
#     'lat': 41.908745,
#     'lon': -87.648308000001},
#    {'stpid': '15354',
#     'stpnm': 'Halsted & Cermak',
#     'lat': 41.852328,
#     'lon': -87.646571999998},
#    {'stpid': '15347',
#     'stpnm': 'Halsted & Chicago',
#     'lat': 41.895940000001,
#     'lon': -87.647840999998},
#    {'stpid': '14908',
#     'stpnm': 'Halsted & Clark/Barry',
#     'lat': 41.937843999999,
#     'lon': -87.649283},
#    {'stpid': '5759',
#     'stpnm': 'Halsted & Cornelia',
#     'lat': 41.945591,
#     'lon': -87.649513999999},
#    {'stpid': '5809',
#     'stpnm': 'Halsted & Cullerton',
#     'lat': 41.855473999999,
#     'lon': -87.646652999999},
#    {'stpid': '5772',
#     'stpnm': 'Halsted & Dickens',
#     'lat': 41.920109,
#     'lon': -87.648661999998},
#    {'stpid': '14907',
#     'stpnm': 'Halsted & Diversey',
#     'lat': 41.932434000001,
#     'lon': -87.649097999999},
#    {'stpid': '15273',
#     'stpnm': 'Halsted & Division',
#     'lat': 41.903298000001,
#     'lon': -87.648155000001},
#    {'stpid': '5788',
#     'stpnm': 'Halsted & Erie',
#     'lat': 41.893974999999,
#     'lon': -87.647774999999},
#    {'stpid': '5780',
#     'stpnm': 'Halsted & Evergreen',
#     'lat': 41.906517,
#     'lon': -87.648254999999},
#    {'stpid': '5149',
#     'stpnm': 'Halsted & Exchange',
#     'lat': 41.818302,
#     'lon': -87.645876999998},
#    {'stpid': '5792',
#     'stpnm': 'Halsted & Fulton Market',
#     'lat': 41.886929,
#     'lon': -87.647602000002},
#    {'stpid': '5836',
#     'stpnm': 'Halsted & Garfield ',
#     'lat': 41.794418,
#     'lon': -87.645261000002},
#    {'stpid': '5837',
#     'stpnm': 'Halsted & Garfield ',
#     'lat': 41.793586999999,
#     'lon': -87.645251999998},
#    {'stpid': '5765',
#     'stpnm': 'Halsted & George',
#     'lat': 41.934682000001,
#     'lon': -87.649182000002},
#    {'stpid': '4638',
#     'stpnm': 'Halsted & Harrison',
#     'lat': 41.873890999999,
#     'lon': -87.647237999999},
#    {'stpid': '5799',
#     'stpnm': 'Halsted & Jackson',
#     'lat': 41.878091,
#     'lon': -87.647328000002},
#    {'stpid': '15350',
#     'stpnm': 'Halsted & Lake',
#     'lat': 41.885352,
#     'lon': -87.647564},
#    {'stpid': '18436',
#     'stpnm': 'Halsted & Lincoln/Fullerton',
#     'lat': 41.925165,
#     'lon': -87.648846000001},
#    {'stpid': '15008',
#     'stpnm': 'Halsted & Madison',
#     'lat': 41.881402999999,
#     'lon': -87.647431999998},
#    {'stpid': '17953',
#     'stpnm': 'Halsted & Marquette Rd',
#     'lat': 41.772198999999,
#     'lon': -87.644685000002},
#    {'stpid': '5802',
#     'stpnm': 'Halsted & Maxwell',
#     'lat': 41.864901999999,
#     'lon': -87.646931},
#    {'stpid': '5790',
#     'stpnm': 'Halsted & Milwaukee/Grand (Blue Line)',
#     'lat': 41.89159,
#     'lon': -87.647712999998},
#    {'stpid': '15352',
#     'stpnm': 'Halsted & Monroe',
#     'lat': 41.880217000001,
#     'lon': -87.647392},
#    {'stpid': '15407',
#     'stpnm': 'Halsted & North Ave (Red Line)',
#     'lat': 41.910582,
#     'lon': -87.648356999999},
#    {'stpid': '16125',
#     'stpnm': 'Halsted & North Branch',
#     'lat': 41.898727000001,
#     'lon': -87.647959},
#    {'stpid': '14863',
#     'stpnm': 'Halsted & Pershing',
#     'lat': 41.823098,
#     'lon': -87.645999999999},
#    {'stpid': '4639',
#     'stpnm': 'Halsted & Polk',
#     'lat': 41.872085000001,
#     'lon': -87.647179000002},
#    {'stpid': '15351',
#     'stpnm': 'Halsted & Randolph/Washington',
#     'lat': 41.883833,
#     'lon': -87.647514000001},
#    {'stpid': '17366',
#     'stpnm': 'Halsted & Roosevelt',
#     'lat': 41.866747,
#     'lon': -87.646999},
#    {'stpid': '5760',
#     'stpnm': 'Halsted & Roscoe',
#     'lat': 41.943749999999,
#     'lon': -87.649473999999},
#    {'stpid': '5767',
#     'stpnm': 'Halsted & Schubert',
#     'lat': 41.931471,
#     'lon': -87.649069},
#    {'stpid': '4640',
#     'stpnm': 'Halsted & Taylor',
#     'lat': 41.869861999999,
#     'lon': -87.647116},
#    {'stpid': '5756',
#     'stpnm': 'Halsted & Waveland/Broadway Terminal',
#     'lat': 41.949802,
#     'lon': -87.649177999999},
#    {'stpid': '5771',
#     'stpnm': 'Halsted & Webster',
#     'lat': 41.921964,
#     'lon': -87.648736},
#    {'stpid': '5764',
#     'stpnm': 'Halsted & Wellington',
#     'lat': 41.936551000001,
#     'lon': -87.649242999999},
#    {'stpid': '5775',
#     'stpnm': 'Halsted & Willow',
#     'lat': 41.914005000001,
#     'lon': -87.648464999998},
#    {'stpid': '5768',
#     'stpnm': 'Halsted & Wrightwood',
#     'lat': 41.929222999999,
#     'lon': -87.648988000001},
#    {'stpid': '5917',
#     'stpnm': 'Halsted Orange Line Station',
#     'lat': 41.846907,
#     'lon': -87.647689},
#    {'stpid': '205',
#     'stpnm': 'UIC-Halsted Blue Line Station',
#     'lat': 41.875558,
#     'lon': -87.647191999999},
#    {'stpid': '5757',
#     'stpnm': 'Waveland & Broadway',
#     'lat': 41.949149999999,
#     'lon': -87.648781999999}]}}

# %% [markdown]
# ## GET Bustime Predictions

# %%
tracker.getpredictions(stpid='5776')
# Out:
# {'bustime-response': {'prd': [{'tmstmp': '20250717 21:55:40',
#     'typ': 'A',
#     'stpnm': '1700 N Halsted',
#     'stpid': '5776',
#     'vid': '8403',
#     'dstp': 958,
#     'rt': '8',
#     'rtdd': '8',
#     'rtdir': 'Southbound',
#     'des': '79th',
#     'prdtm': '20250717 21:56:41',
#     'tablockid': '8 -767',
#     'tatripid': '1078425',
#     'origtatripno': '265254976',
#     'dly': False,
#     'dyn': 0,
#     'prdctdn': 'DUE',
#     'zone': '',
#     'psgld': '',
#     'stst': 77970,
#     'stsd': '2025-07-17',
#     'flagstop': 0},
#    {'tmstmp': '20250717 21:55:20',
#     'typ': 'A',
#     'stpnm': '1700 N Halsted',
#     'stpid': '5776',
#     'vid': '8452',
#     'dstp': 14322,
#     'rt': '8',
#     'rtdd': '8',
#     'rtdir': 'Southbound',
#     'des': '79th',
#     'prdtm': '20250717 22:14:54',
#     'tablockid': '8 -768',
#     'tatripid': '1078426',
#     'origtatripno': '265254977',
#     'dly': False,
#     'dyn': 0,
#     'prdctdn': '19',
#     'zone': '',
#     'psgld': '',
#     'stst': 78990,
#     'stsd': '2025-07-17',
#     'flagstop': 0}]}}

# %% [markdown]
# ## GET Vehicles

# %%
tracker.getvehicles(vid='7991')
# Out:
# {'bustime-response': {'error': [{'vid': '7991',
#     'msg': 'No data found for parameter'}]}}

# %% [markdown]
# ## GET Patterns (road segments)

# %%
tracker.getpatterns(rt='8')
# Out:
# {'bustime-response': {'ptr': [{'pid': 9376,
#     'ln': 74398.0,
#     'rtdir': 'Northbound',
#     'pt': [{'seq': 1,
#       'lat': 41.749730000001,
#       'lon': -87.643648000001,
#       'typ': 'S',
#       'stpid': '3681',
#       'stpnm': 'Halsted & 79th Street Terminal',
#       'pdist': 0.0},
#      {'seq': 2, 'lat': 41.74976, 'lon': -87.64365, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 3, 'lat': 41.74976, 'lon': -87.64401, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 4, 'lat': 41.75098, 'lon': -87.64404, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 5,
#       'lat': 41.750982,
#       'lon': -87.643961999999,
#       'typ': 'S',
#       'stpid': '17510',
#       'stpnm': 'Halsted & 79th Street',
#       'pdist': 541.0},
#      {'seq': 6, 'lat': 41.75098, 'lon': -87.64404, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 7, 'lat': 41.75233, 'lon': -87.64407, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 8,
#       'lat': 41.752331999999,
#       'lon': -87.644010000001,
#       'typ': 'S',
#       'stpid': '5866',
#       'stpnm': 'Halsted & 78th Street',
#       'pdist': 1032.0},
#      {'seq': 9, 'lat': 41.75233, 'lon': -87.64407, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 10, 'lat': 41.75461, 'lon': -87.64414, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 11,
#       'lat': 41.754608000001,
#       'lon': -87.644064000002,
#       'typ': 'S',
#       'stpid': '15085',
#       'stpnm': 'Halsted & 77th Street',
#       'pdist': 1860.0},
#      {'seq': 12, 'lat': 41.75461, 'lon': -87.64414, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 13, 'lat': 41.75636, 'lon': -87.64421, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 14,
#       'lat': 41.756358000001,
#       'lon': -87.644117999998,
#       'typ': 'S',
#       'stpid': '17231',
#       'stpnm': 'Halsted & 76th Street',
#       'pdist': 2494.0},
#      {'seq': 15, 'lat': 41.75636, 'lon': -87.64421, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 16, 'lat': 41.75762, 'lon': -87.64422, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 17,
#       'lat': 41.757622999999,
#       'lon': -87.644144,
#       'typ': 'S',
#       'stpid': '5869',
#       'stpnm': 'Halsted & 75th Street ',
#       'pdist': 2953.0},
#      {'seq': 18, 'lat': 41.75762, 'lon': -87.64422, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 19, 'lat': 41.75962, 'lon': -87.64428, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 20,
#       'lat': 41.759621999999,
#       'lon': -87.644194000001,
#       'typ': 'S',
#       'stpid': '5870',
#       'stpnm': 'Halsted & 74th Street',
#       'pdist': 3682.0},
#      {'seq': 21, 'lat': 41.75962, 'lon': -87.64428, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 22, 'lat': 41.76147, 'lon': -87.64432, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 23,
#       'lat': 41.761470000001,
#       'lon': -87.644243999999,
#       'typ': 'S',
#       'stpid': '5871',
#       'stpnm': 'Halsted & 73rd Street',
#       'pdist': 4358.0},
#      {'seq': 24, 'lat': 41.76147, 'lon': -87.64432, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 25, 'lat': 41.76328, 'lon': -87.64435, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 26,
#       'lat': 41.763279999999,
#       'lon': -87.644299999999,
#       'typ': 'S',
#       'stpid': '5872',
#       'stpnm': 'Halsted & 72nd Street',
#       'pdist': 5017.0},
#      {'seq': 27, 'lat': 41.76328, 'lon': -87.64435, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 28, 'lat': 41.76508, 'lon': -87.64441, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 29,
#       'lat': 41.765084000001,
#       'lon': -87.644336000001,
#       'typ': 'S',
#       'stpid': '5873',
#       'stpnm': 'Halsted & 71st Street',
#       'pdist': 5669.0},
#      {'seq': 30, 'lat': 41.76508, 'lon': -87.64441, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 31, 'lat': 41.76691, 'lon': -87.64447, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 32,
#       'lat': 41.766908,
#       'lon': -87.644375999999,
#       'typ': 'S',
#       'stpid': '5874',
#       'stpnm': 'Halsted & 70th Street',
#       'pdist': 6339.0},
#      {'seq': 33, 'lat': 41.76691, 'lon': -87.64447, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 34, 'lat': 41.76916, 'lon': -87.64452, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 35,
#       'lat': 41.769164,
#       'lon': -87.644431,
#       'typ': 'S',
#       'stpid': '14495',
#       'stpnm': 'Halsted & 69th Street',
#       'pdist': 7157.0},
#      {'seq': 36, 'lat': 41.76916, 'lon': -87.64452, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 37, 'lat': 41.77055, 'lon': -87.64456, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 38,
#       'lat': 41.770548,
#       'lon': -87.644471999998,
#       'typ': 'S',
#       'stpid': '5876',
#       'stpnm': 'Halsted & 68th Street',
#       'pdist': 7665.0},
#      {'seq': 39, 'lat': 41.77055, 'lon': -87.64456, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 40, 'lat': 41.77236, 'lon': -87.64459, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 41,
#       'lat': 41.772363000001,
#       'lon': -87.644515,
#       'typ': 'S',
#       'stpid': '5877',
#       'stpnm': 'Halsted & Marquette Rd',
#       'pdist': 8326.0},
#      {'seq': 42, 'lat': 41.77236, 'lon': -87.64459, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 43, 'lat': 41.77419, 'lon': -87.64464, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 44,
#       'lat': 41.774192,
#       'lon': -87.644537999998,
#       'typ': 'S',
#       'stpid': '5878',
#       'stpnm': 'Halsted & 66th Street',
#       'pdist': 8995.0},
#      {'seq': 45, 'lat': 41.77419, 'lon': -87.64464, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 46, 'lat': 41.77637, 'lon': -87.64469, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 47, 'lat': 41.77647, 'lon': -87.64465, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 48,
#       'lat': 41.776417999999,
#       'lon': -87.644592,
#       'typ': 'S',
#       'stpid': '5879',
#       'stpnm': 'Halsted & 65th Street',
#       'pdist': 9826.0},
#      {'seq': 49, 'lat': 41.77647, 'lon': -87.64465, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 50, 'lat': 41.77874, 'lon': -87.6447, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 51,
#       'lat': 41.778726,
#       'lon': -87.644654999999,
#       'typ': 'S',
#       'stpid': '5881',
#       'stpnm': 'Halsted Green Line Station',
#       'pdist': 10655.0},
#      {'seq': 52, 'lat': 41.77874, 'lon': -87.6447, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 53, 'lat': 41.77978, 'lon': -87.64471, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 54, 'lat': 41.78013, 'lon': -87.64473, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 55,
#       'lat': 41.780115999999,
#       'lon': -87.644679,
#       'typ': 'S',
#       'stpid': '15874',
#       'stpnm': 'Halsted & 63rd Street',
#       'pdist': 11162.0},
#      {'seq': 56, 'lat': 41.78013, 'lon': -87.64473, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 57, 'lat': 41.78201, 'lon': -87.64479, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 58,
#       'lat': 41.782013999999,
#       'lon': -87.644740000001,
#       'typ': 'S',
#       'stpid': '15872',
#       'stpnm': 'Halsted & 63rd Parkway',
#       'pdist': 11847.0},
#      {'seq': 59, 'lat': 41.78201, 'lon': -87.64479, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 60, 'lat': 41.78231, 'lon': -87.64487, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 61, 'lat': 41.78326, 'lon': -87.64487, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 62,
#       'lat': 41.783266000001,
#       'lon': -87.644768999999,
#       'typ': 'S',
#       'stpid': '5884',
#       'stpnm': 'Halsted & 61st Street',
#       'pdist': 12308.0},
#      {'seq': 63, 'lat': 41.78326, 'lon': -87.64487, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 64, 'lat': 41.78489, 'lon': -87.64491, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 65,
#       'lat': 41.784894,
#       'lon': -87.644811999998,
#       'typ': 'S',
#       'stpid': '5885',
#       'stpnm': 'Halsted & 60th Street ',
#       'pdist': 12902.0},
#      {'seq': 66, 'lat': 41.78489, 'lon': -87.64491, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 67, 'lat': 41.7874, 'lon': -87.64498, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 68,
#       'lat': 41.787399,
#       'lon': -87.644896000001,
#       'typ': 'S',
#       'stpid': '14856',
#       'stpnm': 'Halsted & 59th Street',
#       'pdist': 13814.0},
#      {'seq': 69, 'lat': 41.7874, 'lon': -87.64498, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 70, 'lat': 41.78875, 'lon': -87.64498, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 71,
#       'lat': 41.788752999999,
#       'lon': -87.644934000001,
#       'typ': 'S',
#       'stpid': '5887',
#       'stpnm': 'Halsted & 58th Street',
#       'pdist': 14305.0},
#      {'seq': 72, 'lat': 41.78875, 'lon': -87.64498, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 73, 'lat': 41.79097, 'lon': -87.64506, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 74,
#       'lat': 41.790972,
#       'lon': -87.644992000002,
#       'typ': 'S',
#       'stpid': '17400',
#       'stpnm': 'Halsted & 57th Street',
#       'pdist': 15122.0},
#      {'seq': 75, 'lat': 41.79097, 'lon': -87.64506, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 76, 'lat': 41.79234, 'lon': -87.6451, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 77,
#       'lat': 41.792342,
#       'lon': -87.645030000001,
#       'typ': 'S',
#       'stpid': '5889',
#       'stpnm': 'Halsted & 56th Street',
#       'pdist': 15621.0},
#      {'seq': 78, 'lat': 41.79234, 'lon': -87.6451, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 79, 'lat': 41.79385, 'lon': -87.64513, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 80,
#       'lat': 41.793847000001,
#       'lon': -87.645067999999,
#       'typ': 'S',
#       'stpid': '5890',
#       'stpnm': 'Halsted & Garfield ',
#       'pdist': 16173.0},
#      {'seq': 81, 'lat': 41.79385, 'lon': -87.64513, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 82, 'lat': 41.79454, 'lon': -87.64517, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 83,
#       'lat': 41.794536999999,
#       'lon': -87.645071000002,
#       'typ': 'S',
#       'stpid': '5891',
#       'stpnm': 'Halsted & Garfield ',
#       'pdist': 16426.0},
#      {'seq': 84, 'lat': 41.79454, 'lon': -87.64517, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 85, 'lat': 41.79604, 'lon': -87.64521, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 86,
#       'lat': 41.796033,
#       'lon': -87.645126999999,
#       'typ': 'S',
#       'stpid': '5892',
#       'stpnm': 'Halsted & 54th Street',
#       'pdist': 16971.0},
#      {'seq': 87, 'lat': 41.79604, 'lon': -87.64521, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 88, 'lat': 41.79826, 'lon': -87.64526, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 89,
#       'lat': 41.798226,
#       'lon': -87.645183999999,
#       'typ': 'S',
#       'stpid': '17951',
#       'stpnm': 'Halsted & 53rd Street',
#       'pdist': 17782.0},
#      {'seq': 90, 'lat': 41.79826, 'lon': -87.64526, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 91, 'lat': 41.79965, 'lon': -87.6453, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 92,
#       'lat': 41.799648999999,
#       'lon': -87.645218000001,
#       'typ': 'S',
#       'stpid': '5894',
#       'stpnm': 'Halsted & 52nd Street',
#       'pdist': 18289.0},
#      {'seq': 93, 'lat': 41.79965, 'lon': -87.6453, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 94, 'lat': 41.80148, 'lon': -87.64534, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 95,
#       'lat': 41.801480000001,
#       'lon': -87.645263,
#       'typ': 'S',
#       'stpid': '5895',
#       'stpnm': 'Halsted & 51st Street',
#       'pdist': 18956.0},
#      {'seq': 96, 'lat': 41.80148, 'lon': -87.64534, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 97, 'lat': 41.8033, 'lon': -87.64539, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 98,
#       'lat': 41.803299000001,
#       'lon': -87.645315,
#       'typ': 'S',
#       'stpid': '5896',
#       'stpnm': 'Halsted & 50th Street',
#       'pdist': 19619.0},
#      {'seq': 99, 'lat': 41.8033, 'lon': -87.64539, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 100, 'lat': 41.80555, 'lon': -87.64545, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 101,
#       'lat': 41.805511000001,
#       'lon': -87.645367,
#       'typ': 'S',
#       'stpid': '17378',
#       'stpnm': 'Halsted & 49th Street',
#       'pdist': 20443.0},
#      {'seq': 102, 'lat': 41.80555, 'lon': -87.64545, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 103, 'lat': 41.80693, 'lon': -87.64548, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 104,
#       'lat': 41.806929,
#       'lon': -87.645403,
#       'typ': 'S',
#       'stpid': '5898',
#       'stpnm': 'Halsted & 48th Street',
#       'pdist': 20948.0},
#      {'seq': 105, 'lat': 41.80693, 'lon': -87.64548, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 106, 'lat': 41.80928, 'lon': -87.64555, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 107,
#       'lat': 41.809233,
#       'lon': -87.645435000001,
#       'typ': 'S',
#       'stpid': '5086',
#       'stpnm': 'Halsted & 47th Street',
#       'pdist': 21805.0},
#      {'seq': 108, 'lat': 41.80928, 'lon': -87.64555, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 109, 'lat': 41.8106, 'lon': -87.64558, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 110,
#       'lat': 41.810605,
#       'lon': -87.645459999998,
#       'typ': 'S',
#       'stpid': '5087',
#       'stpnm': 'Halsted & 46th Street',
#       'pdist': 22287.0},
#      {'seq': 111, 'lat': 41.8106, 'lon': -87.64558, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 112, 'lat': 41.81282, 'lon': -87.64564, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 113,
#       'lat': 41.812825999999,
#       'lon': -87.645535999999,
#       'typ': 'S',
#       'stpid': '5088',
#       'stpnm': 'Halsted & 45th Street',
#       'pdist': 23098.0},
#      {'seq': 114, 'lat': 41.81282, 'lon': -87.64564, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 115, 'lat': 41.81472, 'lon': -87.64569, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 116,
#       'lat': 41.814716999999,
#       'lon': -87.645605000001,
#       'typ': 'S',
#       'stpid': '5090',
#       'stpnm': 'Halsted & 43rd Place',
#       'pdist': 23788.0},
#      {'seq': 117, 'lat': 41.81472, 'lon': -87.64569, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 118, 'lat': 41.81608, 'lon': -87.64572, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 119,
#       'lat': 41.816078999999,
#       'lon': -87.645635,
#       'typ': 'S',
#       'stpid': '5091',
#       'stpnm': 'Halsted & 43rd Street',
#       'pdist': 24282.0},
#      {'seq': 120, 'lat': 41.81608, 'lon': -87.64572, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 121, 'lat': 41.8174, 'lon': -87.64576, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 122,
#       'lat': 41.817398999999,
#       'lon': -87.645683,
#       'typ': 'S',
#       'stpid': '5092',
#       'stpnm': 'Halsted & 42nd Street',
#       'pdist': 24763.0},
#      {'seq': 123, 'lat': 41.8174, 'lon': -87.64576, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 124, 'lat': 41.81806, 'lon': -87.64578, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 125,
#       'lat': 41.818235,
#       'lon': -87.645722,
#       'typ': 'W',
#       'pdist': 0.0},
#      {'seq': 126, 'lat': 41.81855, 'lon': -87.64573, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 127,
#       'lat': 41.818553,
#       'lon': -87.645701000001,
#       'typ': 'S',
#       'stpid': '5093',
#       'stpnm': 'Halsted & Root',
#       'pdist': 25185.0},
#      {'seq': 128, 'lat': 41.81855, 'lon': -87.64573, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 129, 'lat': 41.8202, 'lon': -87.64581, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 130,
#       'lat': 41.820207,
#       'lon': -87.64575,
#       'typ': 'S',
#       'stpid': '5900',
#       'stpnm': 'Halsted & 41st Street',
#       'pdist': 25788.0},
#      {'seq': 131, 'lat': 41.8202, 'lon': -87.64581, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 132, 'lat': 41.82334, 'lon': -87.64588, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 133,
#       'lat': 41.823340999999,
#       'lon': -87.645825,
#       'typ': 'S',
#       'stpid': '5901',
#       'stpnm': 'Halsted & Pershing',
#       'pdist': 26938.0},
#      {'seq': 134, 'lat': 41.82334, 'lon': -87.64588, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 135, 'lat': 41.82516, 'lon': -87.64597, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 136,
#       'lat': 41.825163,
#       'lon': -87.645896999999,
#       'typ': 'S',
#       'stpid': '5902',
#       'stpnm': 'Halsted & 38th Street ',
#       'pdist': 27605.0},
#      {'seq': 137, 'lat': 41.82516, 'lon': -87.64597, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 138, 'lat': 41.82699, 'lon': -87.64601, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 139,
#       'lat': 41.826991000001,
#       'lon': -87.645942999999,
#       'typ': 'S',
#       'stpid': '5903',
#       'stpnm': 'Halsted & 37th Street ',
#       'pdist': 28272.0},
#      {'seq': 140, 'lat': 41.82699, 'lon': -87.64601, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 141, 'lat': 41.82883, 'lon': -87.64605, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 142,
#       'lat': 41.828830000001,
#       'lon': -87.645990999998,
#       'typ': 'S',
#       'stpid': '5904',
#       'stpnm': 'Halsted & 36th Street ',
#       'pdist': 28938.0},
#      {'seq': 143, 'lat': 41.82883, 'lon': -87.64605, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 144, 'lat': 41.83062, 'lon': -87.6461, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 145,
#       'lat': 41.830623999999,
#       'lon': -87.646018000001,
#       'typ': 'S',
#       'stpid': '5905',
#       'stpnm': 'Halsted & 35th Street',
#       'pdist': 29587.0},
#      {'seq': 146, 'lat': 41.83062, 'lon': -87.6461, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 147, 'lat': 41.83247, 'lon': -87.64613, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 148,
#       'lat': 41.832475000001,
#       'lon': -87.646071,
#       'typ': 'S',
#       'stpid': '5906',
#       'stpnm': 'Halsted & 34th Street ',
#       'pdist': 30260.0},
#      {'seq': 149, 'lat': 41.83247, 'lon': -87.64613, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 150, 'lat': 41.83428, 'lon': -87.64619, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 151,
#       'lat': 41.834283999999,
#       'lon': -87.646115,
#       'typ': 'S',
#       'stpid': '5907',
#       'stpnm': 'Halsted & 33rd Street ',
#       'pdist': 30919.0},
#      {'seq': 152, 'lat': 41.83428, 'lon': -87.64619, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 153, 'lat': 41.83635, 'lon': -87.64622, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 154,
#       'lat': 41.836355,
#       'lon': -87.646160000001,
#       'typ': 'S',
#       'stpid': '5908',
#       'stpnm': 'Halsted & 32nd Street',
#       'pdist': 31671.0},
#      {'seq': 155, 'lat': 41.83635, 'lon': -87.64622, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 156, 'lat': 41.83835, 'lon': -87.64627, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 157,
#       'lat': 41.838351999999,
#       'lon': -87.646190999999,
#       'typ': 'S',
#       'stpid': '16050',
#       'stpnm': 'Halsted & 31st Street',
#       'pdist': 32404.0},
#      {'seq': 158, 'lat': 41.83835, 'lon': -87.64627, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 159, 'lat': 41.84019, 'lon': -87.64633, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 160,
#       'lat': 41.840185999999,
#       'lon': -87.646240999998,
#       'typ': 'S',
#       'stpid': '18212',
#       'stpnm': 'Halsted & 30th Street',
#       'pdist': 33072.0},
#      {'seq': 161, 'lat': 41.84019, 'lon': -87.64633, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 162, 'lat': 41.84201, 'lon': -87.64638, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 163,
#       'lat': 41.842007,
#       'lon': -87.646282999999,
#       'typ': 'S',
#       'stpid': '18215',
#       'stpnm': 'Halsted & 29th Street',
#       'pdist': 33737.0},
#      {'seq': 164, 'lat': 41.84201, 'lon': -87.64638, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 165, 'lat': 41.8434, 'lon': -87.64641, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 166,
#       'lat': 41.843404,
#       'lon': -87.646315999999,
#       'typ': 'S',
#       'stpid': '5912',
#       'stpnm': 'Halsted & 28th Street',
#       'pdist': 34243.0},
#      {'seq': 167, 'lat': 41.8434, 'lon': -87.64641, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 168, 'lat': 41.84522, 'lon': -87.64644, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 169,
#       'lat': 41.845222000001,
#       'lon': -87.646363,
#       'typ': 'S',
#       'stpid': '5914',
#       'stpnm': 'Halsted & 26th Street',
#       'pdist': 34907.0},
#      {'seq': 170, 'lat': 41.84522, 'lon': -87.64644, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 171, 'lat': 41.84531, 'lon': -87.64644, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 172,
#       'lat': 41.847136,
#       'lon': -87.646486,
#       'typ': 'W',
#       'pdist': 0.0},
#      {'seq': 173,
#       'lat': 41.847154,
#       'lon': -87.646639,
#       'typ': 'W',
#       'pdist': 0.0},
#      {'seq': 174,
#       'lat': 41.84694,
#       'lon': -87.647224,
#       'typ': 'W',
#       'pdist': 0.0},
#      {'seq': 175,
#       'lat': 41.846962,
#       'lon': -87.647291,
#       'typ': 'W',
#       'pdist': 0.0},
#      {'seq': 176, 'lat': 41.84693, 'lon': -87.64757, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 177, 'lat': 41.84688, 'lon': -87.64767, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 178,
#       'lat': 41.846907,
#       'lon': -87.647689,
#       'typ': 'S',
#       'stpid': '5917',
#       'stpnm': 'Halsted Orange Line Station',
#       'pdist': 35957.0},
#      {'seq': 179, 'lat': 41.84688, 'lon': -87.64767, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 180,
#       'lat': 41.846704,
#       'lon': -87.648032,
#       'typ': 'W',
#       'pdist': 0.0},
#      {'seq': 181,
#       'lat': 41.846528,
#       'lon': -87.648394,
#       'typ': 'W',
#       'pdist': 0.0},
#      {'seq': 182,
#       'lat': 41.846377,
#       'lon': -87.648434,
#       'typ': 'W',
#       'pdist': 0.0},
#      {'seq': 183,
#       'lat': 41.846311,
#       'lon': -87.648386,
#       'typ': 'W',
#       'pdist': 0.0},
#      {'seq': 184,
#       'lat': 41.846297,
#       'lon': -87.648303,
#       'typ': 'W',
#       'pdist': 0.0},
#      {'seq': 185, 'lat': 41.847114, 'lon': -87.6466, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 186,
#       'lat': 41.847316,
#       'lon': -87.646442,
#       'typ': 'W',
#       'pdist': 0.0},
#      {'seq': 187, 'lat': 41.85006, 'lon': -87.64638, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 188, 'lat': 41.85018, 'lon': -87.64644, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 189, 'lat': 41.85084, 'lon': -87.64644, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 190,
#       'lat': 41.850842999999,
#       'lon': -87.646364999998,
#       'typ': 'S',
#       'stpid': '5918',
#       'stpnm': '2300 S Halsted',
#       'pdist': 38228.0},
#      {'seq': 191, 'lat': 41.85084, 'lon': -87.64644, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 192, 'lat': 41.85294, 'lon': -87.6465, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 193,
#       'lat': 41.852949999999,
#       'lon': -87.646409000001,
#       'typ': 'S',
#       'stpid': '18571',
#       'stpnm': 'Halsted & Cermak',
#       'pdist': 38993.0},
#      {'seq': 194, 'lat': 41.85294, 'lon': -87.6465, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 195, 'lat': 41.85527, 'lon': -87.64657, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 196,
#       'lat': 41.855273999999,
#       'lon': -87.646489,
#       'typ': 'S',
#       'stpid': '5921',
#       'stpnm': 'Halsted & Cullerton',
#       'pdist': 39838.0},
#      {'seq': 197, 'lat': 41.85527, 'lon': -87.64657, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 198, 'lat': 41.85745, 'lon': -87.64663, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 199,
#       'lat': 41.857449,
#       'lon': -87.646548,
#       'typ': 'S',
#       'stpid': '4615',
#       'stpnm': 'Halsted & 18th Street',
#       'pdist': 40628.0},
#      {'seq': 200, 'lat': 41.85745, 'lon': -87.64663, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 201, 'lat': 41.85978, 'lon': -87.6467, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 202,
#       'lat': 41.859779,
#       'lon': -87.646633,
#       'typ': 'S',
#       'stpid': '5924',
#       'stpnm': 'Halsted & 16th Street',
#       'pdist': 41477.0},
#      {'seq': 203, 'lat': 41.85978, 'lon': -87.6467, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 204, 'lat': 41.86223, 'lon': -87.64676, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 205,
#       'lat': 41.862227,
#       'lon': -87.646690999999,
#       'typ': 'S',
#       'stpid': '5926',
#       'stpnm': 'Halsted & 14th Place',
#       'pdist': 42370.0},
#      {'seq': 206, 'lat': 41.86223, 'lon': -87.64676, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 207, 'lat': 41.86469, 'lon': -87.64684, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 208,
#       'lat': 41.864689,
#       'lon': -87.646765,
#       'typ': 'S',
#       'stpid': '5928',
#       'stpnm': 'Halsted & Maxwell',
#       'pdist': 43269.0},
#      {'seq': 209, 'lat': 41.86469, 'lon': -87.64684, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 210, 'lat': 41.8675, 'lon': -87.64691, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 211,
#       'lat': 41.8675,
#       'lon': -87.646809999998,
#       'typ': 'S',
#       'stpid': '14777',
#       'stpnm': 'Halsted & Roosevelt',
#       'pdist': 44299.0},
#      {'seq': 212, 'lat': 41.8675, 'lon': -87.64691, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 213, 'lat': 41.86825, 'lon': -87.64692, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 214, 'lat': 41.8684, 'lon': -87.64686, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 215, 'lat': 41.87011, 'lon': -87.64689, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 216,
#       'lat': 41.870112,
#       'lon': -87.646849000001,
#       'typ': 'S',
#       'stpid': '14487',
#       'stpnm': 'Halsted & Taylor',
#       'pdist': 45257.0},
#      {'seq': 217, 'lat': 41.87011, 'lon': -87.64689, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 218, 'lat': 41.87178, 'lon': -87.64694, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 219,
#       'lat': 41.871777,
#       'lon': -87.646922,
#       'typ': 'S',
#       'stpid': '4618',
#       'stpnm': 'Halsted & Polk',
#       'pdist': 45870.0},
#      {'seq': 220, 'lat': 41.87178, 'lon': -87.64694, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 221, 'lat': 41.87417, 'lon': -87.64705, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 222, 'lat': 41.87442, 'lon': -87.64713, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 223, 'lat': 41.87543, 'lon': -87.64718, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 224,
#       'lat': 41.875501000001,
#       'lon': -87.647069000002,
#       'typ': 'S',
#       'stpid': '18184',
#       'stpnm': 'UIC-Halsted Blue Line Station',
#       'pdist': 47248.0},
#      {'seq': 225, 'lat': 41.87553, 'lon': -87.64719, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 226, 'lat': 41.87832, 'lon': -87.64724, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 227,
#       'lat': 41.87832,
#       'lon': -87.647174999999,
#       'typ': 'S',
#       'stpid': '18009',
#       'stpnm': 'Halsted & Jackson',
#       'pdist': 48267.0},
#      {'seq': 228, 'lat': 41.87832, 'lon': -87.64724, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 229, 'lat': 41.8804, 'lon': -87.64732, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 230,
#       'lat': 41.880400000001,
#       'lon': -87.647245000001,
#       'typ': 'S',
#       'stpid': '5931',
#       'stpnm': 'Halsted & Monroe',
#       'pdist': 49020.0},
#      {'seq': 231, 'lat': 41.8804, 'lon': -87.64732, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 232, 'lat': 41.88218, 'lon': -87.64737, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 233,
#       'lat': 41.882144000001,
#       'lon': -87.647291000001,
#       'typ': 'S',
#       'stpid': '440',
#       'stpnm': 'Halsted & Madison',
#       'pdist': 49669.0},
#      {'seq': 234, 'lat': 41.88218, 'lon': -87.64737, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 235, 'lat': 41.88483, 'lon': -87.64745, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 236,
#       'lat': 41.884820000001,
#       'lon': -87.647363,
#       'typ': 'S',
#       'stpid': '18011',
#       'stpnm': 'Halsted & Randolph',
#       'pdist': 50631.0},
#      {'seq': 237, 'lat': 41.88483, 'lon': -87.64745, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 238, 'lat': 41.88605, 'lon': -87.64748, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 239,
#       'lat': 41.886046,
#       'lon': -87.6474,
#       'typ': 'S',
#       'stpid': '15356',
#       'stpnm': 'Halsted & Lake',
#       'pdist': 51022.0},
#      {'seq': 240, 'lat': 41.88605, 'lon': -87.64748, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 241, 'lat': 41.89042, 'lon': -87.64761, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 242,
#       'lat': 41.890418999999,
#       'lon': -87.647534000001,
#       'typ': 'S',
#       'stpid': '5936',
#       'stpnm': 'Halsted & Hubbard',
#       'pdist': 52627.0},
#      {'seq': 243, 'lat': 41.89042, 'lon': -87.64761, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 244, 'lat': 41.89119, 'lon': -87.64762, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 245, 'lat': 41.89147, 'lon': -87.64763, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 246,
#       'lat': 41.891474000001,
#       'lon': -87.647547999998,
#       'typ': 'S',
#       'stpid': '15274',
#       'stpnm': 'Halsted & Milwaukee/Grand (Blue Line)',
#       'pdist': 53008.0},
#      {'seq': 247, 'lat': 41.89147, 'lon': -87.64763, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 248, 'lat': 41.89389, 'lon': -87.6477, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 249,
#       'lat': 41.893902000001,
#       'lon': -87.647629000002,
#       'typ': 'S',
#       'stpid': '15363',
#       'stpnm': 'Halsted & Erie',
#       'pdist': 53895.0},
#      {'seq': 250, 'lat': 41.89389, 'lon': -87.64768, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 251, 'lat': 41.89496, 'lon': -87.64769, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 252, 'lat': 41.89497, 'lon': -87.64768, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 253, 'lat': 41.89687, 'lon': -87.64772, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 254,
#       'lat': 41.896826999999,
#       'lon': -87.647608999999,
#       'typ': 'S',
#       'stpid': '5941',
#       'stpnm': 'Halsted & Chicago',
#       'pdist': 54983.0},
#      {'seq': 255, 'lat': 41.89687, 'lon': -87.64772, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 256, 'lat': 41.8977, 'lon': -87.64785, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 257,
#       'lat': 41.898986,
#       'lon': -87.647885,
#       'typ': 'W',
#       'pdist': 0.0},
#      {'seq': 258, 'lat': 41.89932, 'lon': -87.6479, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 259,
#       'lat': 41.899322000001,
#       'lon': -87.647796999999,
#       'typ': 'S',
#       'stpid': '15405',
#       'stpnm': 'Halsted & North Branch',
#       'pdist': 55883.0},
#      {'seq': 260, 'lat': 41.89932, 'lon': -87.6479, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 261, 'lat': 41.90363, 'lon': -87.64809, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 262, 'lat': 41.90377, 'lon': -87.6481, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 263,
#       'lat': 41.903866,
#       'lon': -87.648044,
#       'typ': 'W',
#       'pdist': 0.0},
#      {'seq': 264,
#       'lat': 41.903962000001,
#       'lon': -87.647986999999,
#       'typ': 'S',
#       'stpid': '15151',
#       'stpnm': 'Halsted & Division',
#       'pdist': 57570.0},
#      {'seq': 265, 'lat': 41.90396, 'lon': -87.6481, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 266, 'lat': 41.90626, 'lon': -87.64816, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 267,
#       'lat': 41.906259,
#       'lon': -87.648073000001,
#       'typ': 'S',
#       'stpid': '5947',
#       'stpnm': 'Halsted & Evergreen',
#       'pdist': 58409.0},
#      {'seq': 268, 'lat': 41.90626, 'lon': -87.64816, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 269, 'lat': 41.90887, 'lon': -87.64823, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 270,
#       'lat': 41.908873,
#       'lon': -87.648144999999,
#       'typ': 'S',
#       'stpid': '15406',
#       'stpnm': 'Halsted & Blackhawk',
#       'pdist': 59363.0},
#      {'seq': 271, 'lat': 41.90887, 'lon': -87.64823, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 272, 'lat': 41.91079, 'lon': -87.64827, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 273,
#       'lat': 41.910793999999,
#       'lon': -87.648185000001,
#       'typ': 'S',
#       'stpid': '5950',
#       'stpnm': 'Halsted & North Ave',
#       'pdist': 60067.0},
#      {'seq': 274, 'lat': 41.91079, 'lon': -87.64827, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 275, 'lat': 41.91272, 'lon': -87.64834, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 276,
#       'lat': 41.91272,
#       'lon': -87.648288,
#       'typ': 'S',
#       'stpid': '5951',
#       'stpnm': '1700 N Halsted',
#       'pdist': 60770.0},
#      {'seq': 277, 'lat': 41.91272, 'lon': -87.64834, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 278, 'lat': 41.91373, 'lon': -87.64837, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 279,
#       'lat': 41.913730000001,
#       'lon': -87.648278,
#       'typ': 'S',
#       'stpid': '5952',
#       'stpnm': 'Halsted & Willow',
#       'pdist': 61139.0},
#      {'seq': 280, 'lat': 41.91373, 'lon': -87.64837, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 281, 'lat': 41.91592, 'lon': -87.64844, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 282,
#       'lat': 41.915922999999,
#       'lon': -87.648399999999,
#       'typ': 'S',
#       'stpid': '5953',
#       'stpnm': '1900 N Halsted',
#       'pdist': 61935.0},
#      {'seq': 283, 'lat': 41.91592, 'lon': -87.64844, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 284, 'lat': 41.91837, 'lon': -87.64852, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 285,
#       'lat': 41.918359,
#       'lon': -87.648448999999,
#       'typ': 'S',
#       'stpid': '18469',
#       'stpnm': 'Halsted & Armitage',
#       'pdist': 62832.0},
#      {'seq': 286, 'lat': 41.91837, 'lon': -87.64852, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 287, 'lat': 41.92022, 'lon': -87.64859, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 288,
#       'lat': 41.920221999999,
#       'lon': -87.648497000001,
#       'typ': 'S',
#       'stpid': '18240',
#       'stpnm': 'Halsted & Dickens',
#       'pdist': 63505.0},
#      {'seq': 289, 'lat': 41.92022, 'lon': -87.64859, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 290, 'lat': 41.92172, 'lon': -87.64864, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 291,
#       'lat': 41.921722,
#       'lon': -87.648553000002,
#       'typ': 'S',
#       'stpid': '5956',
#       'stpnm': 'Halsted & Webster',
#       'pdist': 64051.0},
#      {'seq': 292, 'lat': 41.92172, 'lon': -87.64864, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 293, 'lat': 41.92351, 'lon': -87.6487, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 294,
#       'lat': 41.923515000001,
#       'lon': -87.648627999999,
#       'typ': 'S',
#       'stpid': '5957',
#       'stpnm': 'Halsted & Belden',
#       'pdist': 64704.0},
#      {'seq': 295, 'lat': 41.92351, 'lon': -87.6487, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 296, 'lat': 41.92545, 'lon': -87.64876, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 297, 'lat': 41.92577, 'lon': -87.64878, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 298,
#       'lat': 41.925775,
#       'lon': -87.648689999999,
#       'typ': 'S',
#       'stpid': '17487',
#       'stpnm': 'Halsted & Lincoln/Fullerton',
#       'pdist': 65527.0},
#      {'seq': 299, 'lat': 41.92577, 'lon': -87.64878, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 300, 'lat': 41.92732, 'lon': -87.64883, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 301,
#       'lat': 41.927323,
#       'lon': -87.648744999999,
#       'typ': 'S',
#       'stpid': '5959',
#       'stpnm': 'Halsted & Altgeld',
#       'pdist': 66092.0},
#      {'seq': 302, 'lat': 41.92732, 'lon': -87.64883, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 303, 'lat': 41.92897, 'lon': -87.64889, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 304,
#       'lat': 41.928973,
#       'lon': -87.6488,
#       'typ': 'S',
#       'stpid': '5960',
#       'stpnm': 'Halsted & Wrightwood',
#       'pdist': 66697.0},
#      {'seq': 305, 'lat': 41.92897, 'lon': -87.64889, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 306, 'lat': 41.93146, 'lon': -87.64897, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 307,
#       'lat': 41.931458999999,
#       'lon': -87.648887,
#       'typ': 'S',
#       'stpid': '5961',
#       'stpnm': 'Halsted & Schubert',
#       'pdist': 67604.0},
#      {'seq': 308, 'lat': 41.93146, 'lon': -87.64897, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 309, 'lat': 41.93307, 'lon': -87.64903, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 310,
#       'lat': 41.933057,
#       'lon': -87.648939999999,
#       'typ': 'S',
#       'stpid': '14909',
#       'stpnm': 'Halsted & Diversey',
#       'pdist': 68191.0},
#      {'seq': 311, 'lat': 41.93307, 'lon': -87.64903, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 312, 'lat': 41.93467, 'lon': -87.64909, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 313,
#       'lat': 41.934670999999,
#       'lon': -87.648998000001,
#       'typ': 'S',
#       'stpid': '5963',
#       'stpnm': 'Halsted & George',
#       'pdist': 68775.0},
#      {'seq': 314, 'lat': 41.93467, 'lon': -87.64909, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 315, 'lat': 41.93664, 'lon': -87.64916, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 316,
#       'lat': 41.936597999999,
#       'lon': -87.649073,
#       'typ': 'S',
#       'stpid': '14910',
#       'stpnm': 'Halsted & Wellington',
#       'pdist': 69497.0},
#      {'seq': 317, 'lat': 41.93664, 'lon': -87.64916, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 318, 'lat': 41.9384, 'lon': -87.64923, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 319,
#       'lat': 41.938405000001,
#       'lon': -87.649129999999,
#       'typ': 'S',
#       'stpid': '14911',
#       'stpnm': 'Halsted & Clark/Barry',
#       'pdist': 70141.0},
#      {'seq': 320, 'lat': 41.9384, 'lon': -87.64923, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 321, 'lat': 41.93986, 'lon': -87.64927, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 322,
#       'lat': 41.939865,
#       'lon': -87.649182,
#       'typ': 'S',
#       'stpid': '5966',
#       'stpnm': 'Halsted & Belmont',
#       'pdist': 70675.0},
#      {'seq': 323, 'lat': 41.93986, 'lon': -87.64927, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 324, 'lat': 41.94169, 'lon': -87.64933, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 325,
#       'lat': 41.941693,
#       'lon': -87.649249000001,
#       'typ': 'S',
#       'stpid': '5967',
#       'stpnm': 'Halsted & Aldine',
#       'pdist': 71343.0},
#      {'seq': 326, 'lat': 41.94169, 'lon': -87.64933, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 327, 'lat': 41.94349, 'lon': -87.64937, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 328,
#       'lat': 41.943503999999,
#       'lon': -87.649290000001,
#       'typ': 'S',
#       'stpid': '5968',
#       'stpnm': 'Halsted & Roscoe',
#       'pdist': 72002.0},
#      {'seq': 329, 'lat': 41.94349, 'lon': -87.64937, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 330, 'lat': 41.94535, 'lon': -87.64943, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 331,
#       'lat': 41.945329000001,
#       'lon': -87.649356,
#       'typ': 'S',
#       'stpid': '5969',
#       'stpnm': 'Halsted & Cornelia',
#       'pdist': 72681.0},
#      {'seq': 332, 'lat': 41.94535, 'lon': -87.64943, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 333, 'lat': 41.94717, 'lon': -87.64947, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 334,
#       'lat': 41.947170000001,
#       'lon': -87.649398,
#       'typ': 'S',
#       'stpid': '5970',
#       'stpnm': 'Halsted & Addison',
#       'pdist': 73344.0},
#      {'seq': 335, 'lat': 41.94717, 'lon': -87.64947, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 336, 'lat': 41.94811, 'lon': -87.64952, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 337,
#       'lat': 41.948234,
#       'lon': -87.649478,
#       'typ': 'W',
#       'pdist': 0.0},
#      {'seq': 338,
#       'lat': 41.949267,
#       'lon': -87.649488,
#       'typ': 'W',
#       'pdist': 0.0},
#      {'seq': 339,
#       'lat': 41.949396,
#       'lon': -87.649488999998,
#       'typ': 'S',
#       'stpid': '17390',
#       'stpnm': 'Halsted & Waveland',
#       'pdist': 74157.0},
#      {'seq': 340,
#       'lat': 41.949795,
#       'lon': -87.649522,
#       'typ': 'W',
#       'pdist': 0.0},
#      {'seq': 341,
#       'lat': 41.949813,
#       'lon': -87.649283,
#       'typ': 'W',
#       'pdist': 0.0},
#      {'seq': 342,
#       'lat': 41.949802,
#       'lon': -87.649177999999,
#       'typ': 'S',
#       'stpid': '5756',
#       'stpnm': 'Halsted & Waveland/Broadway Terminal',
#       'pdist': 74398.0}]},
#    {'pid': 9368,
#     'ln': 74847.0,
#     'rtdir': 'Southbound',
#     'pt': [{'seq': 1,
#       'lat': 41.949802,
#       'lon': -87.649177999999,
#       'typ': 'S',
#       'stpid': '5756',
#       'stpnm': 'Halsted & Waveland/Broadway Terminal',
#       'pdist': 0.0},
#      {'seq': 2, 'lat': 41.949805, 'lon': -87.648766, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 3, 'lat': 41.94916, 'lon': -87.64837, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 4, 'lat': 41.94915, 'lon': -87.64842, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 5, 'lat': 41.94915, 'lon': -87.64853, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 6, 'lat': 41.94914, 'lon': -87.64878, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 7,
#       'lat': 41.949149999999,
#       'lon': -87.648781999999,
#       'typ': 'S',
#       'stpid': '5757',
#       'stpnm': 'Waveland & Broadway',
#       'pdist': 481.0},
#      {'seq': 8, 'lat': 41.94914, 'lon': -87.64878, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 9, 'lat': 41.94912, 'lon': -87.64955, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 10, 'lat': 41.94713, 'lon': -87.64947, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 11,
#       'lat': 41.947033,
#       'lon': -87.649513,
#       'typ': 'W',
#       'pdist': 0.0},
#      {'seq': 12,
#       'lat': 41.946935000001,
#       'lon': -87.649554999999,
#       'typ': 'S',
#       'stpid': '14901',
#       'stpnm': 'Halsted & Addison',
#       'pdist': 1489.0},
#      {'seq': 13, 'lat': 41.9466, 'lon': -87.64945, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 14, 'lat': 41.94557, 'lon': -87.64943, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 15,
#       'lat': 41.945591,
#       'lon': -87.649513999999,
#       'typ': 'S',
#       'stpid': '5759',
#       'stpnm': 'Halsted & Cornelia',
#       'pdist': 1989.0},
#      {'seq': 16, 'lat': 41.94557, 'lon': -87.64943, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 17, 'lat': 41.94375, 'lon': -87.64938, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 18,
#       'lat': 41.943749999999,
#       'lon': -87.649473999999,
#       'typ': 'S',
#       'stpid': '5760',
#       'stpnm': 'Halsted & Roscoe',
#       'pdist': 2654.0},
#      {'seq': 19, 'lat': 41.94375, 'lon': -87.64938, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 20, 'lat': 41.94191, 'lon': -87.64932, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 21,
#       'lat': 41.941912999999,
#       'lon': -87.649409000001,
#       'typ': 'S',
#       'stpid': '5761',
#       'stpnm': 'Halsted & Aldine',
#       'pdist': 3331.0},
#      {'seq': 22, 'lat': 41.94191, 'lon': -87.64932, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 23, 'lat': 41.93997, 'lon': -87.64928, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 24, 'lat': 41.93971, 'lon': -87.64927, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 25,
#       'lat': 41.939709,
#       'lon': -87.649349,
#       'typ': 'S',
#       'stpid': '14906',
#       'stpnm': 'Halsted & Belmont',
#       'pdist': 4131.0},
#      {'seq': 26, 'lat': 41.93971, 'lon': -87.64927, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 27, 'lat': 41.93785, 'lon': -87.6492, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 28,
#       'lat': 41.937843999999,
#       'lon': -87.649283,
#       'typ': 'S',
#       'stpid': '14908',
#       'stpnm': 'Halsted & Clark/Barry',
#       'pdist': 4812.0},
#      {'seq': 29, 'lat': 41.93785, 'lon': -87.6492, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 30, 'lat': 41.93655, 'lon': -87.64917, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 31,
#       'lat': 41.936551000001,
#       'lon': -87.649242999999,
#       'typ': 'S',
#       'stpid': '5764',
#       'stpnm': 'Halsted & Wellington',
#       'pdist': 5287.0},
#      {'seq': 32, 'lat': 41.93655, 'lon': -87.64917, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 33, 'lat': 41.93468, 'lon': -87.64908, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 34,
#       'lat': 41.934682000001,
#       'lon': -87.649182000002,
#       'typ': 'S',
#       'stpid': '5765',
#       'stpnm': 'Halsted & George',
#       'pdist': 5973.0},
#      {'seq': 35, 'lat': 41.93468, 'lon': -87.64908, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 36, 'lat': 41.93243, 'lon': -87.649, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 37,
#       'lat': 41.932434000001,
#       'lon': -87.649097999999,
#       'typ': 'S',
#       'stpid': '14907',
#       'stpnm': 'Halsted & Diversey',
#       'pdist': 6797.0},
#      {'seq': 38, 'lat': 41.93243, 'lon': -87.649, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 39, 'lat': 41.93147, 'lon': -87.64897, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 40,
#       'lat': 41.931471,
#       'lon': -87.649069,
#       'typ': 'S',
#       'stpid': '5767',
#       'stpnm': 'Halsted & Schubert',
#       'pdist': 7147.0},
#      {'seq': 41, 'lat': 41.93147, 'lon': -87.64897, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 42, 'lat': 41.92922, 'lon': -87.64889, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 43,
#       'lat': 41.929222999999,
#       'lon': -87.648988000001,
#       'typ': 'S',
#       'stpid': '5768',
#       'stpnm': 'Halsted & Wrightwood',
#       'pdist': 7967.0},
#      {'seq': 44, 'lat': 41.92922, 'lon': -87.64889, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 45, 'lat': 41.92722, 'lon': -87.64882, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 46,
#       'lat': 41.927222,
#       'lon': -87.648923,
#       'typ': 'S',
#       'stpid': '5769',
#       'stpnm': 'Halsted & Altgeld',
#       'pdist': 8694.0},
#      {'seq': 47, 'lat': 41.92722, 'lon': -87.64882, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 48, 'lat': 41.92546, 'lon': -87.64875, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 49, 'lat': 41.92516, 'lon': -87.64876, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 50,
#       'lat': 41.925165,
#       'lon': -87.648846000001,
#       'typ': 'S',
#       'stpid': '18436',
#       'stpnm': 'Halsted & Lincoln/Fullerton',
#       'pdist': 9446.0},
#      {'seq': 51, 'lat': 41.92516, 'lon': -87.64876, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 52, 'lat': 41.92377, 'lon': -87.64872, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 53,
#       'lat': 41.923765999999,
#       'lon': -87.648787,
#       'typ': 'S',
#       'stpid': '1349',
#       'stpnm': 'Halsted & Belden',
#       'pdist': 9952.0},
#      {'seq': 54, 'lat': 41.92377, 'lon': -87.64872, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 55, 'lat': 41.92196, 'lon': -87.64865, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 56,
#       'lat': 41.921964,
#       'lon': -87.648736,
#       'typ': 'S',
#       'stpid': '5771',
#       'stpnm': 'Halsted & Webster',
#       'pdist': 10616.0},
#      {'seq': 57, 'lat': 41.92196, 'lon': -87.64865, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 58, 'lat': 41.92011, 'lon': -87.64857, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 59,
#       'lat': 41.920109,
#       'lon': -87.648661999998,
#       'typ': 'S',
#       'stpid': '5772',
#       'stpnm': 'Halsted & Dickens',
#       'pdist': 11291.0},
#      {'seq': 60, 'lat': 41.92011, 'lon': -87.64857, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 61, 'lat': 41.91791, 'lon': -87.6485, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 62,
#       'lat': 41.917924,
#       'lon': -87.648602999999,
#       'typ': 'S',
#       'stpid': '18468',
#       'stpnm': 'Halsted & Armitage',
#       'pdist': 12093.0},
#      {'seq': 63, 'lat': 41.91791, 'lon': -87.6485, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 64, 'lat': 41.91598, 'lon': -87.64844, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 65,
#       'lat': 41.916024999999,
#       'lon': -87.648524,
#       'typ': 'S',
#       'stpid': '5774',
#       'stpnm': '1900 N Halsted',
#       'pdist': 12800.0},
#      {'seq': 66, 'lat': 41.91598, 'lon': -87.64844, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 67, 'lat': 41.91401, 'lon': -87.64838, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 68,
#       'lat': 41.914005000001,
#       'lon': -87.648464999998,
#       'typ': 'S',
#       'stpid': '5775',
#       'stpnm': 'Halsted & Willow',
#       'pdist': 13515.0},
#      {'seq': 69, 'lat': 41.91401, 'lon': -87.64838, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 70, 'lat': 41.91178, 'lon': -87.64831, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 71,
#       'lat': 41.911779000001,
#       'lon': -87.648394,
#       'typ': 'S',
#       'stpid': '5776',
#       'stpnm': '1700 N Halsted',
#       'pdist': 14328.0},
#      {'seq': 72, 'lat': 41.91178, 'lon': -87.64831, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 73, 'lat': 41.91058, 'lon': -87.64827, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 74,
#       'lat': 41.910582,
#       'lon': -87.648356999999,
#       'typ': 'S',
#       'stpid': '15407',
#       'stpnm': 'Halsted & North Ave (Red Line)',
#       'pdist': 14764.0},
#      {'seq': 75, 'lat': 41.91058, 'lon': -87.64827, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 76, 'lat': 41.90875, 'lon': -87.64822, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 77,
#       'lat': 41.908745,
#       'lon': -87.648308000001,
#       'typ': 'S',
#       'stpid': '5779',
#       'stpnm': 'Halsted & Blackhawk',
#       'pdist': 15432.0},
#      {'seq': 78, 'lat': 41.90875, 'lon': -87.64822, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 79, 'lat': 41.90652, 'lon': -87.64817, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 80,
#       'lat': 41.906517,
#       'lon': -87.648254999999,
#       'typ': 'S',
#       'stpid': '5780',
#       'stpnm': 'Halsted & Evergreen',
#       'pdist': 16244.0},
#      {'seq': 81, 'lat': 41.90652, 'lon': -87.64817, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 82, 'lat': 41.90363, 'lon': -87.64809, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 83, 'lat': 41.9033, 'lon': -87.64809, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 84,
#       'lat': 41.903298000001,
#       'lon': -87.648155000001,
#       'typ': 'S',
#       'stpid': '15273',
#       'stpnm': 'Halsted & Division',
#       'pdist': 17418.0},
#      {'seq': 85, 'lat': 41.9033, 'lon': -87.64809, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 86, 'lat': 41.898855, 'lon': -87.64788, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 87, 'lat': 41.89873, 'lon': -87.64788, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 88,
#       'lat': 41.898727000001,
#       'lon': -87.647959,
#       'typ': 'S',
#       'stpid': '16125',
#       'stpnm': 'Halsted & North Branch',
#       'pdist': 19090.0},
#      {'seq': 89, 'lat': 41.89873, 'lon': -87.64788, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 90, 'lat': 41.8977, 'lon': -87.64785, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 91, 'lat': 41.89762, 'lon': -87.64789, 'typ': 'W', 'pdist': 0.0},
# ...
#      {'seq': 218,
#       'lat': 41.825726999999,
#       'lon': -87.646065999999,
#       'typ': 'S',
#       'stpid': '5825',
#       'stpnm': 'Halsted & 38th Street ',
#       'pdist': 47008.0},
#      {'seq': 219, 'lat': 41.82573, 'lon': -87.64599, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 220, 'lat': 41.82308, 'lon': -87.64597, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 221,
#       'lat': 41.823098,
#       'lon': -87.645999999999,
#       'typ': 'S',
#       'stpid': '14863',
#       'stpnm': 'Halsted & Pershing',
#       'pdist': 47974.0},
#      {'seq': 222, 'lat': 41.8231, 'lon': -87.64595, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 223, 'lat': 41.82021, 'lon': -87.64589, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 224,
#       'lat': 41.820213,
#       'lon': -87.645930999999,
#       'typ': 'S',
#       'stpid': '5827',
#       'stpnm': 'Halsted & 41st Street',
#       'pdist': 49030.0},
#      {'seq': 225, 'lat': 41.82021, 'lon': -87.64589, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 226, 'lat': 41.8183, 'lon': -87.64584, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 227,
#       'lat': 41.818302,
#       'lon': -87.645876999998,
#       'typ': 'S',
#       'stpid': '5149',
#       'stpnm': 'Halsted & Exchange',
#       'pdist': 49729.0},
#      {'seq': 228, 'lat': 41.8183, 'lon': -87.64584, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 229, 'lat': 41.81813, 'lon': -87.64584, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 230, 'lat': 41.81806, 'lon': -87.64577, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 231, 'lat': 41.81756, 'lon': -87.64577, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 232,
#       'lat': 41.817558999999,
#       'lon': -87.645861,
#       'typ': 'S',
#       'stpid': '5150',
#       'stpnm': 'Halsted & 42nd Street',
#       'pdist': 50007.0},
#      {'seq': 233, 'lat': 41.81756, 'lon': -87.64577, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 234, 'lat': 41.81588, 'lon': -87.64572, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 235,
#       'lat': 41.815874999999,
#       'lon': -87.64581,
#       'typ': 'S',
#       'stpid': '17060',
#       'stpnm': 'Halsted & 43rd Street',
#       'pdist': 50622.0},
#      {'seq': 236, 'lat': 41.81588, 'lon': -87.64572, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 237, 'lat': 41.81451, 'lon': -87.64569, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 238,
#       'lat': 41.814509000001,
#       'lon': -87.645777,
#       'typ': 'S',
#       'stpid': '17170',
#       'stpnm': 'Halsted & 43rd Place',
#       'pdist': 51121.0},
#      {'seq': 239, 'lat': 41.81451, 'lon': -87.64569, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 240, 'lat': 41.81216, 'lon': -87.64563, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 241,
#       'lat': 41.812157999999,
#       'lon': -87.645727,
#       'typ': 'S',
#       'stpid': '17158',
#       'stpnm': 'Halsted & 45th Street',
#       'pdist': 51978.0},
#      {'seq': 242, 'lat': 41.81216, 'lon': -87.64563, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 243, 'lat': 41.81035, 'lon': -87.64557, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 244,
#       'lat': 41.810345,
#       'lon': -87.645680999999,
#       'typ': 'S',
#       'stpid': '5155',
#       'stpnm': 'Halsted & 46th Street',
#       'pdist': 52636.0},
#      {'seq': 245, 'lat': 41.81035, 'lon': -87.64557, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 246, 'lat': 41.80847, 'lon': -87.64552, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 247,
#       'lat': 41.808529000001,
#       'lon': -87.645638000001,
#       'typ': 'S',
#       'stpid': '16127',
#       'stpnm': 'Halsted & 47th Street',
#       'pdist': 53324.0},
#      {'seq': 248, 'lat': 41.80847, 'lon': -87.64552, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 249, 'lat': 41.80716, 'lon': -87.64549, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 250,
#       'lat': 41.807158999999,
#       'lon': -87.645588000001,
#       'typ': 'S',
#       'stpid': '5829',
#       'stpnm': 'Halsted & 48th Street',
#       'pdist': 53804.0},
#      {'seq': 251, 'lat': 41.80716, 'lon': -87.64549, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 252, 'lat': 41.80554, 'lon': -87.64545, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 253,
#       'lat': 41.805541,
#       'lon': -87.645541,
#       'typ': 'S',
#       'stpid': '5830',
#       'stpnm': 'Halsted & 49th Street',
#       'pdist': 54397.0},
#      {'seq': 254, 'lat': 41.80554, 'lon': -87.64545, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 255, 'lat': 41.80351, 'lon': -87.64539, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 256,
#       'lat': 41.803505999999,
#       'lon': -87.645481999999,
#       'typ': 'S',
#       'stpid': '5831',
#       'stpnm': 'Halsted & 50th Street',
#       'pdist': 55133.0},
#      {'seq': 257, 'lat': 41.80351, 'lon': -87.64539, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 258, 'lat': 41.80136, 'lon': -87.64534, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 259,
#       'lat': 41.801359999999,
#       'lon': -87.645435,
#       'typ': 'S',
#       'stpid': '15023',
#       'stpnm': 'Halsted & 51st Street',
#       'pdist': 55919.0},
#      {'seq': 260, 'lat': 41.80136, 'lon': -87.64534, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 261, 'lat': 41.7999, 'lon': -87.64531, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 262,
#       'lat': 41.799895,
#       'lon': -87.645399999999,
#       'typ': 'S',
#       'stpid': '5833',
#       'stpnm': 'Halsted & 52nd Street',
#       'pdist': 56454.0},
#      {'seq': 263, 'lat': 41.7999, 'lon': -87.64531, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 264, 'lat': 41.79753, 'lon': -87.64524, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 265,
#       'lat': 41.797531000001,
#       'lon': -87.64534,
#       'typ': 'S',
#       'stpid': '17950',
#       'stpnm': 'Halsted & 53rd Street',
#       'pdist': 57320.0},
#      {'seq': 266, 'lat': 41.79753, 'lon': -87.64524, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 267, 'lat': 41.79618, 'lon': -87.64521, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 268,
#       'lat': 41.796182,
#       'lon': -87.645302999999,
#       'typ': 'S',
#       'stpid': '5835',
#       'stpnm': 'Halsted & 54th Street',
#       'pdist': 57816.0},
#      {'seq': 269, 'lat': 41.79618, 'lon': -87.64521, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 270, 'lat': 41.79442, 'lon': -87.64517, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 271,
#       'lat': 41.794418,
#       'lon': -87.645261000002,
#       'typ': 'S',
#       'stpid': '5836',
#       'stpnm': 'Halsted & Garfield ',
#       'pdist': 58456.0},
#      {'seq': 272, 'lat': 41.79442, 'lon': -87.64517, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 273, 'lat': 41.79359, 'lon': -87.64512, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 274,
#       'lat': 41.793586999999,
#       'lon': -87.645251999998,
#       'typ': 'S',
#       'stpid': '5837',
#       'stpnm': 'Halsted & Garfield ',
#       'pdist': 58759.0},
#      {'seq': 275, 'lat': 41.79359, 'lon': -87.64512, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 276, 'lat': 41.7926, 'lon': -87.6451, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 277,
#       'lat': 41.792594999999,
#       'lon': -87.645209999998,
#       'typ': 'S',
#       'stpid': '5838',
#       'stpnm': 'Halsted & 56th Street',
#       'pdist': 59121.0},
#      {'seq': 278, 'lat': 41.7926, 'lon': -87.6451, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 279, 'lat': 41.79078, 'lon': -87.64505, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 280,
#       'lat': 41.790780999999,
#       'lon': -87.645162000001,
#       'typ': 'S',
#       'stpid': '5839',
#       'stpnm': 'Halsted & 57th Street',
#       'pdist': 59788.0},
#      {'seq': 281, 'lat': 41.79078, 'lon': -87.64505, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 282, 'lat': 41.78898, 'lon': -87.64501, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 283,
#       'lat': 41.788979000001,
#       'lon': -87.645116999999,
#       'typ': 'S',
#       'stpid': '5840',
#       'stpnm': 'Halsted & 58th Street',
#       'pdist': 60440.0},
#      {'seq': 284, 'lat': 41.78898, 'lon': -87.64501, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 285, 'lat': 41.78719, 'lon': -87.64497, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 286,
#       'lat': 41.787191,
#       'lon': -87.64508,
#       'typ': 'S',
#       'stpid': '5841',
#       'stpnm': 'Halsted & 59th Street',
#       'pdist': 61091.0},
#      {'seq': 287, 'lat': 41.78719, 'lon': -87.64497, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 288, 'lat': 41.78531, 'lon': -87.64492, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 289,
#       'lat': 41.785306999999,
#       'lon': -87.645043000002,
#       'typ': 'S',
#       'stpid': '5842',
#       'stpnm': 'Halsted & 60th Street ',
#       'pdist': 61775.0},
#      {'seq': 290, 'lat': 41.78531, 'lon': -87.64492, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 291, 'lat': 41.78302, 'lon': -87.64488, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 292,
#       'lat': 41.783072000001,
#       'lon': -87.644987000001,
#       'typ': 'S',
#       'stpid': '17373',
#       'stpnm': 'Halsted & 61st Street',
#       'pdist': 62611.0},
#      {'seq': 293, 'lat': 41.78302, 'lon': -87.64488, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 294, 'lat': 41.78231, 'lon': -87.64487, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 295, 'lat': 41.78215, 'lon': -87.64494, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 296, 'lat': 41.78185, 'lon': -87.64493, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 297,
#       'lat': 41.781846,
#       'lon': -87.644960000001,
#       'typ': 'S',
#       'stpid': '15873',
#       'stpnm': 'Halsted & 63rd Parkway',
#       'pdist': 63041.0},
#      {'seq': 298, 'lat': 41.78185, 'lon': -87.64493, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 299, 'lat': 41.77977, 'lon': -87.64484, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 300, 'lat': 41.77938, 'lon': -87.64482, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 301,
#       'lat': 41.779376000001,
#       'lon': -87.644862999998,
#       'typ': 'S',
#       'stpid': '15875',
#       'stpnm': 'Halsted & 63rd Street (Green Line)',
#       'pdist': 63947.0},
#      {'seq': 302, 'lat': 41.77938, 'lon': -87.64482, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 303, 'lat': 41.77804, 'lon': -87.64481, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 304,
#       'lat': 41.778039000001,
#       'lon': -87.644870999999,
#       'typ': 'S',
#       'stpid': '5848',
#       'stpnm': '6400 S Halsted',
#       'pdist': 64436.0},
#      {'seq': 305, 'lat': 41.77804, 'lon': -87.64481, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 306, 'lat': 41.7764, 'lon': -87.64473, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 307, 'lat': 41.77637, 'lon': -87.64469, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 308, 'lat': 41.77577, 'lon': -87.64469, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 309,
#       'lat': 41.775765,
#       'lon': -87.644795,
#       'typ': 'S',
#       'stpid': '15876',
#       'stpnm': 'Halsted & 65th Street',
#       'pdist': 65273.0},
#      {'seq': 310, 'lat': 41.77577, 'lon': -87.64469, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 311, 'lat': 41.77441, 'lon': -87.64465, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 312,
#       'lat': 41.774403999999,
#       'lon': -87.644768000002,
#       'typ': 'S',
#       'stpid': '5850',
#       'stpnm': 'Halsted & 66th Street',
#       'pdist': 65768.0},
#      {'seq': 313, 'lat': 41.77441, 'lon': -87.64465, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 314, 'lat': 41.7722, 'lon': -87.64459, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 315,
#       'lat': 41.772198999999,
#       'lon': -87.644685000002,
#       'typ': 'S',
#       'stpid': '17953',
#       'stpnm': 'Halsted & Marquette Rd',
#       'pdist': 66575.0},
#      {'seq': 316, 'lat': 41.7722, 'lon': -87.64459, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 317, 'lat': 41.77077, 'lon': -87.64457, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 318,
#       'lat': 41.770769,
#       'lon': -87.64465,
#       'typ': 'S',
#       'stpid': '5852',
#       'stpnm': 'Halsted & 68th Street',
#       'pdist': 67097.0},
#      {'seq': 319, 'lat': 41.77077, 'lon': -87.64457, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 320, 'lat': 41.76839, 'lon': -87.6445, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 321,
#       'lat': 41.768388999999,
#       'lon': -87.644593,
#       'typ': 'S',
#       'stpid': '14496',
#       'stpnm': 'Halsted & 69th Street',
#       'pdist': 67968.0},
#      {'seq': 322, 'lat': 41.76839, 'lon': -87.6445, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 323, 'lat': 41.76712, 'lon': -87.64447, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 324,
#       'lat': 41.767121,
#       'lon': -87.644550999999,
#       'typ': 'S',
#       'stpid': '5854',
#       'stpnm': 'Halsted & 70th Street',
#       'pdist': 68431.0},
#      {'seq': 325, 'lat': 41.76712, 'lon': -87.64447, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 326, 'lat': 41.76532, 'lon': -87.64441, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 327,
#       'lat': 41.765313999999,
#       'lon': -87.644502,
#       'typ': 'S',
#       'stpid': '5855',
#       'stpnm': 'Halsted & 71st Street',
#       'pdist': 69083.0},
#      {'seq': 328, 'lat': 41.76532, 'lon': -87.64441, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 329, 'lat': 41.76354, 'lon': -87.64436, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 330,
#       'lat': 41.763534999999,
#       'lon': -87.644464999999,
#       'typ': 'S',
#       'stpid': '5856',
#       'stpnm': 'Halsted & 72nd Street',
#       'pdist': 69730.0},
#      {'seq': 331, 'lat': 41.76354, 'lon': -87.64436, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 332, 'lat': 41.76168, 'lon': -87.64432, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 333,
#       'lat': 41.761677,
#       'lon': -87.644418999999,
#       'typ': 'S',
#       'stpid': '5857',
#       'stpnm': 'Halsted & 73rd Street',
#       'pdist': 70408.0},
#      {'seq': 334, 'lat': 41.76168, 'lon': -87.64432, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 335, 'lat': 41.75974, 'lon': -87.64429, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 336, 'lat': 41.75952, 'lon': -87.64428, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 337,
#       'lat': 41.759517,
#       'lon': -87.644356,
#       'typ': 'S',
#       'stpid': '14818',
#       'stpnm': 'Halsted & 74th Street',
#       'pdist': 71200.0},
#      {'seq': 338, 'lat': 41.75952, 'lon': -87.64428, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 339, 'lat': 41.75856, 'lon': -87.64424, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 340,
#       'lat': 41.758557,
#       'lon': -87.644338,
#       'typ': 'S',
#       'stpid': '5859',
#       'stpnm': 'Halsted & 75th Street ',
#       'pdist': 71550.0},
#      {'seq': 341, 'lat': 41.75856, 'lon': -87.64424, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 342, 'lat': 41.75743, 'lon': -87.64421, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 343,
#       'lat': 41.757428,
#       'lon': -87.644305999999,
#       'typ': 'S',
#       'stpid': '5860',
#       'stpnm': 'Halsted & 75th Street ',
#       'pdist': 71962.0},
#      {'seq': 344, 'lat': 41.75743, 'lon': -87.64421, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 345, 'lat': 41.75621, 'lon': -87.6442, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 346,
#       'lat': 41.756206000001,
#       'lon': -87.64428,
#       'typ': 'S',
#       'stpid': '5861',
#       'stpnm': 'Halsted & 76th Street',
#       'pdist': 72408.0},
#      {'seq': 347, 'lat': 41.75621, 'lon': -87.6442, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 348, 'lat': 41.75401, 'lon': -87.64413, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 349,
#       'lat': 41.754011000001,
#       'lon': -87.644217,
#       'typ': 'S',
#       'stpid': '15086',
#       'stpnm': 'Halsted & 77th Street',
#       'pdist': 73209.0},
#      {'seq': 350, 'lat': 41.75401, 'lon': -87.64413, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 351, 'lat': 41.75261, 'lon': -87.64408, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 352,
#       'lat': 41.752605999999,
#       'lon': -87.644187999999,
#       'typ': 'S',
#       'stpid': '5863',
#       'stpnm': 'Halsted & 78th Street',
#       'pdist': 73720.0},
#      {'seq': 353, 'lat': 41.75261, 'lon': -87.64408, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 354, 'lat': 41.75077, 'lon': -87.64403, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 355,
#       'lat': 41.750764999999,
#       'lon': -87.644159999999,
#       'typ': 'S',
#       'stpid': '5864',
#       'stpnm': 'Halsted & 79th Street',
#       'pdist': 74390.0},
#      {'seq': 356, 'lat': 41.75077, 'lon': -87.64403, 'typ': 'W', 'pdist': 0.0},
#      {'seq': 357,
#       'lat': 41.74983,
#       'lon': -87.644023,
#       'typ': 'W',
#       'pdist': 0.0},
#      {'seq': 358,
#       'lat': 41.749789,
#       'lon': -87.643759,
#       'typ': 'W',
#       'pdist': 0.0},
#      {'seq': 359,
#       'lat': 41.749793000001,
#       'lon': -87.643614999998,
#       'typ': 'S',
#       'stpid': '17472',
#       'stpnm': 'Halsted & 79th Street Terminal',
#       'pdist': 74847.0}]}]}}

# %% [markdown]
# ## GET Service Bulletins

# %%
tracker.getservicebulletins(rt='8')
# Out:
# {'bustime-response': {'sb': [{'nm': '8 Alerts',
#     'sbj': 'Check for #8 alerts',
#     'dtl': 'For alerts, maps and detailed route information, visit <a href="https://transitchicago.com/bus/8">#8 Halsted Route Information</a> on our website. You can also sign up to have alerts sent by text or e-mail by signing up for <a href="https://transitchicago.com/updates">CTA Updates</a>.',
#     'brf': 'For alerts and detailed #8 bus route info, visit https://transitchicago.com/bus/8 - get alerts sent to you via transitchicago.com/updates',
#     'prty': 'Low',
#     'srvc': [{'rt': '8', 'rtdir': '', 'stpid': '', 'stpnm': ''}],
#     'mod': '',
#     'url': ''}]}}

# %% [markdown]
# ## GET Detours

# %%
tracker.getdetours(rt='8')
# Out:
# {'bustime-response': {}}

# %% [markdown]
# ## GET Locale List

# %%
tracker.getlocalelist()
# Out:
# {'bustime-response': {'locale': [{'localestring': 'en',
#     'displayname': 'English'},
#    {'localestring': 'es', 'displayname': 'Spanish'}]}}
